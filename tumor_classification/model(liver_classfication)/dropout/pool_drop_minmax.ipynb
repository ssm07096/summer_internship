# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  
os.environ["CUDA_VISIBLE_DEVICES"]="6"

# %%
import numpy as np
from matplotlib import pyplot as plt
import nibabel as nib
from PIL import Image
from matplotlib import pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
from sklearn.model_selection import train_test_split
import torchsummary
from torchvision import transforms
import time
from sklearn.metrics import classification_report

# %%
#파일이름 sort해서 list저장
data_path='/disk1/data_liverbound_noclip/'
name_list=os.listdir(data_path)

segmentation_data = [files[:-4] for files in name_list if files.startswith('segmentation')]
segmentation_data=list(set(segmentation_data))
segmentation_data.sort()
seg_data_test=[]
for i in range(30,45):
    seg_data_test.append(segmentation_data.pop(i))

volume_data=[files[:-4] for files in name_list if files.startswith('volume')]
volume_data=list(set(volume_data))
volume_data.sort()
vol_data_test=[]
for i in range(30,45):
    vol_data_test.append(volume_data.pop(i))

# %%
# all_labels=np.loadtxt('/home/sumins/workspace/liver_classification/all_labels.txt',dtype=int)
# all_labels=all_labels.tolist()

# %%
#npy를 slice별로 나누어 하나의 list저장
seg_list_train=[]
seg_list_test=[]
for file in segmentation_data:
    fname=os.path.basename(file)
    print(fname)
    img_array=np.load(data_path+fname+'.npy')
    
    #print(f'img_num: {img_array.shape}')
    
    if len(img_array.shape) == 3:
        nx, ny, nz = img_array.shape
        total_slices = img_array.shape[2]
        #print(total_slices)
        # iterate through slices
        for current_slice in range(0, total_slices):
            seg_list_train.append(img_array[:,:,current_slice]) 

for file in seg_data_test:
    fname=os.path.basename(file)
    print(fname)
    img_array=np.load(data_path+fname+'.npy')
    
    #print(f'img_num: {img_array.shape}')
    
    if len(img_array.shape) == 3:
        nx, ny, nz = img_array.shape
        total_slices = img_array.shape[2]
        print(total_slices)
        # iterate through slices
        for current_slice in range(0, total_slices):
            seg_list_test.append(img_array[:,:,current_slice]) 
#간 1, 병변 2, 나머지 0


vol_list_train=[]
vol_list_test=[]
for file in volume_data:
    fname=os.path.basename(file)
    print(fname)
    img_array=np.load(data_path+fname+'.npy')
    
    #print(f'img_num: {img_array.shape}')
    
    if len(img_array.shape) == 3:
        nx, ny, nz = img_array.shape
        total_slices = img_array.shape[2]
        # iterate through slices
        for current_slice in range(0, total_slices):
            vol_list_train.append(img_array[:,:,current_slice]) 
            
for file in vol_data_test:
    fname=os.path.basename(file)
    print(fname)
    img_array=np.load(data_path+fname+'.npy')
    
    #print(f'img_num: {img_array.shape}')
    
    if len(img_array.shape) == 3:
        nx, ny, nz = img_array.shape
        total_slices = img_array.shape[2]
        # iterate through slices
        for current_slice in range(0, total_slices):
            vol_list_test.append(img_array[:,:,current_slice])
# Out:
# segmentation-0
# segmentation-1
# segmentation-10
# segmentation-100
# segmentation-101
# segmentation-102
# segmentation-103
# segmentation-104
# segmentation-105
# segmentation-106
# segmentation-107
# segmentation-108
# segmentation-109
# segmentation-11
# segmentation-110
# segmentation-111
# segmentation-112
# segmentation-113
# segmentation-114
# segmentation-115
# segmentation-116
# segmentation-117
# segmentation-118
# segmentation-119
# segmentation-12
# segmentation-120
# segmentation-121
# segmentation-122
# segmentation-123
# segmentation-124
# segmentation-126
# segmentation-128
# segmentation-13
# segmentation-15
# segmentation-17
# segmentation-19
# segmentation-20
# segmentation-22
# segmentation-24
# segmentation-26
# segmentation-28
# segmentation-3
# segmentation-31
# segmentation-33
# segmentation-35
# segmentation-36
# segmentation-37
# segmentation-38
# segmentation-39
# segmentation-4
# segmentation-40
# segmentation-41
# segmentation-42
# segmentation-43
# segmentation-44
# segmentation-45
# segmentation-46
# segmentation-47
# segmentation-48
# segmentation-49
# segmentation-5
# segmentation-50
# segmentation-51
# segmentation-52
# segmentation-53
# segmentation-54
# segmentation-55
# segmentation-56
# segmentation-57
# segmentation-58
# segmentation-59
# segmentation-6
# segmentation-60
# segmentation-61
# segmentation-62
# segmentation-63
# segmentation-64
# segmentation-65
# segmentation-66
# segmentation-67
# segmentation-68
# segmentation-69
# segmentation-7
# segmentation-70
# segmentation-71
# segmentation-72
# segmentation-73
# segmentation-74
# segmentation-75
# segmentation-76
# segmentation-77
# segmentation-78
# segmentation-79
# segmentation-8
# segmentation-80
# segmentation-81
# segmentation-82
# segmentation-83
# segmentation-84
# segmentation-85
# segmentation-86
# segmentation-87
# segmentation-88
# segmentation-89
# segmentation-9
# segmentation-90
# segmentation-91
# segmentation-92
# segmentation-93
# segmentation-94
# segmentation-95
# segmentation-96
# segmentation-97
# segmentation-98
# segmentation-99
# segmentation-125
# 133
# segmentation-127
# 270
# segmentation-129
# 325
# segmentation-14
# 164
# segmentation-16
# 222
# segmentation-18
# 224
# segmentation-2
# 164
# segmentation-21
# 191
# segmentation-23
# 137
# segmentation-25
# 277
# segmentation-27
# 272
# segmentation-29
# 135
# segmentation-30
# 146
# segmentation-32
# 128
# segmentation-34
# 109
# volume-0
# volume-1
# volume-10
# volume-100
# volume-101
# volume-102
# volume-103
# volume-104
# volume-105
# volume-106
# volume-107
# volume-108
# volume-109
# volume-11
# volume-110
# volume-111
# volume-112
# volume-113
# volume-114
# volume-115
# volume-116
# volume-117
# volume-118
# volume-119
# volume-12
# volume-120
# volume-121
# volume-122
# volume-123
# volume-124
# volume-126
# volume-128
# volume-13
# volume-15
# volume-17
# volume-19
# volume-20
# volume-22
# volume-24
# volume-26
# volume-28
# volume-3
# volume-31
# volume-33
# volume-35
# volume-36
# volume-37
# volume-38
# volume-39
# volume-4
# volume-40
# volume-41
# volume-42
# volume-43
# volume-44
# volume-45
# volume-46
# volume-47
# volume-48
# volume-49
# volume-5
# volume-50
# volume-51
# volume-52
# volume-53
# volume-54
# volume-55
# volume-56
# volume-57
# volume-58
# volume-59
# volume-6
# volume-60
# volume-61
# volume-62
# volume-63
# volume-64
# volume-65
# volume-66
# volume-67
# volume-68
# volume-69
# volume-7
# volume-70
# volume-71
# volume-72
# volume-73
# volume-74
# volume-75
# volume-76
# volume-77
# volume-78
# volume-79
# volume-8
# volume-80
# volume-81
# volume-82
# volume-83
# volume-84
# volume-85
# volume-86
# volume-87
# volume-88
# volume-89
# volume-9
# volume-90
# volume-91
# volume-92
# volume-93
# volume-94
# volume-95
# volume-96
# volume-97
# volume-98
# volume-99
# volume-125
# volume-127
# volume-129
# volume-14
# volume-16
# volume-18
# volume-2
# volume-21
# volume-23
# volume-25
# volume-27
# volume-29
# volume-30
# volume-32
# volume-34

# %%
#label을 만들어 list에 저장
labels_train = []
labels_test=[]
for i in seg_list_test:
    if 2 in i:
        labels_test.append(1)
    else:
        labels_test.append(0)
        
for i in seg_list_train:
    if 2 in i:
        labels_train.append(1)
    else:
        labels_train.append(0)

# %%
def norm(nparray):
    # normalize scans to [0,1]
    _min = nparray.min()
    _max = nparray.max()
    nparray = nparray - _min
    nparray = nparray / (_max - _min)
    return nparray

def norm_zscore(nparray):
    # normalize 2d scands by mean and standard deviation
    mean = nparray.mean()
    std = nparray.std()    
    nparray = nparray - mean
    nparray /= std
    return nparray

# %%
WINDOW_MAX = 130
WINDOW_MIN = -30
GLOBAL_PIXEL_MEAN = 0.1

class CustomDataset(Dataset): 
  def __init__(self,volume_list,all_labels,transforms=None):
    self.volume_list=volume_list
    self.all_labels=all_labels
    self.length=len(all_labels)
    self.transforms=transforms


  def __len__(self):
    return self.length


  def __getitem__(self, idx):
    npy=self.volume_list[idx]

    npy[npy > WINDOW_MAX] = WINDOW_MAX
    npy[npy < WINDOW_MIN] = WINDOW_MIN
    
    npy = (npy - WINDOW_MIN) / (WINDOW_MAX - WINDOW_MIN)
    npy -= GLOBAL_PIXEL_MEAN
    
    if len(npy.shape)==2:
      npy=npy[:,:,np.newaxis].astype(dtype='float32')
    
    if self.transforms is not None:
      npy=self.transforms(npy)
    
    return{'npy':npy,'label':self.all_labels[idx]}

# %%
class CustomConvNet(nn.Module):
    def __init__(self):
        super(CustomConvNet, self).__init__() #상속받은 class에 접근하기 위함

        self.layer1 = self.conv_module(1, 16) #흑백사진은 inp
        self.layer2 = self.conv_module(16, 32)
        self.layer3 = self.conv_module(32, 64)
        self.layer4 = self.conv_module(64, 128)
        self.layer5 = self.conv_module(128, 256)
        self.gap = self.global_avg_pool(256, 2)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        out = self.gap(out)
        out = out.view(-1, 2)

        return out

    def conv_module(self, in_num, out_num):
        return nn.Sequential(
            nn.Conv2d(in_num, out_num, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(out_num),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.4))

    def global_avg_pool(self, in_num, out_num):
        return nn.Sequential(
            nn.Conv2d(in_num, out_num, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(out_num),
            nn.LeakyReLU(),
            nn.AdaptiveAvgPool2d((1,1)))
        
model=CustomConvNet()
torchsummary.summary(model.cuda(),input_size=(1,512,512),batch_size=1)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [1, 16, 512, 512]             160
#        BatchNorm2d-2          [1, 16, 512, 512]              32
#          LeakyReLU-3          [1, 16, 512, 512]               0
#          MaxPool2d-4          [1, 16, 256, 256]               0
#            Dropout-5          [1, 16, 256, 256]               0
#             Conv2d-6          [1, 32, 256, 256]           4,640
#        BatchNorm2d-7          [1, 32, 256, 256]              64
#          LeakyReLU-8          [1, 32, 256, 256]               0
#          MaxPool2d-9          [1, 32, 128, 128]               0
#           Dropout-10          [1, 32, 128, 128]               0
#            Conv2d-11          [1, 64, 128, 128]          18,496
#       BatchNorm2d-12          [1, 64, 128, 128]             128
#         LeakyReLU-13          [1, 64, 128, 128]               0
#         MaxPool2d-14            [1, 64, 64, 64]               0
#           Dropout-15            [1, 64, 64, 64]               0
#            Conv2d-16           [1, 128, 64, 64]          73,856
#       BatchNorm2d-17           [1, 128, 64, 64]             256
#         LeakyReLU-18           [1, 128, 64, 64]               0
#         MaxPool2d-19           [1, 128, 32, 32]               0
#           Dropout-20           [1, 128, 32, 32]               0
#            Conv2d-21           [1, 256, 32, 32]         295,168
#       BatchNorm2d-22           [1, 256, 32, 32]             512
#         LeakyReLU-23           [1, 256, 32, 32]               0
#         MaxPool2d-24           [1, 256, 16, 16]               0
#           Dropout-25           [1, 256, 16, 16]               0
#            Conv2d-26             [1, 2, 16, 16]           4,610
#       BatchNorm2d-27             [1, 2, 16, 16]               4
#         LeakyReLU-28             [1, 2, 16, 16]               0
# AdaptiveAvgPool2d-29               [1, 2, 1, 1]               0
# ================================================================
# Total params: 397,926
# Trainable params: 397,926
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 1.00
# Forward/backward pass size (MB): 217.01
# Params size (MB): 1.52
# Estimated Total Size (MB): 219.53
# ----------------------------------------------------------------

# %%
transforms_train = transforms.Compose([transforms.ToTensor()
                                       ])
transforms_test = transforms.Compose([transforms.ToTensor()
                                       ])

hyper_param_epoch=100
hyper_param_batch=32
hyper_param_learning_rate=0.001

# %%
#vol_train, vol_valid, lab_train, lab_valid = train_test_split(volume_list, all_labels, test_size=0.3, shuffle=True, stratify=all_labels, random_state=34)
train_dataset=CustomDataset(volume_list=vol_list_train, all_labels=labels_train,transforms=transforms_train)
test_dataset=CustomDataset(volume_list=vol_list_test,all_labels=labels_test,transforms=transforms_test)
train_loader = DataLoader(train_dataset, batch_size=hyper_param_batch, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=hyper_param_batch, shuffle=True)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device,"/" ,torch.cuda.device_count())

custom_model=CustomConvNet().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(custom_model.parameters(), lr=hyper_param_learning_rate)
# Out:
# cuda:0 / 1

# %%
def validation_loss(model):
    total_loss=0
    for i_batch, item in enumerate(test_loader):
        npys = item['npy'].to(device)
        labels = item['label'].to(device)
 
        outputs =model(npys)
        loss = criterion(outputs, labels)

        total_loss+=loss.item()
    return total_loss/(i_batch+1)

# %%
loss_value=1
start=time.time()
custom_model.train()
train_loss_history=[]
valid_loss_history=[]
val_loss=0
T=0
for e in range(hyper_param_epoch):
        for i_batch, item in enumerate(train_loader):
                npys = item['npy'].to(device)
                labels = item['label'].to(device)
                #print(npys)
                # Forward pass
                outputs =custom_model(npys)
                loss = criterion(outputs, labels)

                # Backward and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                
        val_loss=validation_loss(custom_model)
        train_loss_history.append(loss.item())
        valid_loss_history.append(val_loss)
        print('Epoch [{}/{}],i_batch={} ,Train_Loss: {:.4f},Valid_loss: {:.4f}'
                                        .format(e + 1, hyper_param_epoch, i_batch+1, loss.item(),val_loss))
        print("Time: {}sec".format(time.time()-start))
        start=time.time()
        if loss_value>val_loss:
                loss_value=val_loss
                torch.save({
                'epoch': e,
                'model_state_dict': custom_model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': loss,
                }, '/home/sumins/workspace/model_check/model_dropout_minmax.pth')
# Out:
# Epoch [1/100],i_batch=604 ,Train_Loss: 0.4734,Valid_loss: 0.5643
# Time: 117.3021457195282sec
# Epoch [2/100],i_batch=604 ,Train_Loss: 0.4219,Valid_loss: 0.5600
# Time: 621.6697421073914sec
# Epoch [3/100],i_batch=604 ,Train_Loss: 0.4446,Valid_loss: 0.5598
# Time: 1647.2032251358032sec
# Epoch [4/100],i_batch=604 ,Train_Loss: 0.5472,Valid_loss: 0.5267
# Time: 1088.2662963867188sec
# Epoch [5/100],i_batch=604 ,Train_Loss: 0.4388,Valid_loss: 0.5632
# Time: 1094.3117635250092sec
# Epoch [6/100],i_batch=604 ,Train_Loss: 0.3510,Valid_loss: 0.5361
# Time: 1222.0175545215607sec
# Epoch [7/100],i_batch=604 ,Train_Loss: 0.2778,Valid_loss: 0.5371
# Time: 1175.9522485733032sec
# Epoch [8/100],i_batch=604 ,Train_Loss: 0.4773,Valid_loss: 0.5704
# Time: 1062.489292383194sec
# Epoch [9/100],i_batch=604 ,Train_Loss: 0.2714,Valid_loss: 0.5522
# Time: 1118.3007316589355sec
# Epoch [10/100],i_batch=604 ,Train_Loss: 0.1540,Valid_loss: 0.6342
# Time: 1229.14200258255sec
# Epoch [11/100],i_batch=604 ,Train_Loss: 0.1868,Valid_loss: 0.5399
# Time: 1159.1566643714905sec
# Epoch [12/100],i_batch=604 ,Train_Loss: 0.5202,Valid_loss: 0.5725
# Time: 1087.9031467437744sec
# Epoch [13/100],i_batch=604 ,Train_Loss: 0.3531,Valid_loss: 0.5700
# Time: 1174.1619365215302sec
# Epoch [14/100],i_batch=604 ,Train_Loss: 0.1172,Valid_loss: 0.5572
# Time: 170.2374358177185sec
# Epoch [15/100],i_batch=604 ,Train_Loss: 0.1759,Valid_loss: 0.5961
# Time: 129.2839617729187sec
# Epoch [16/100],i_batch=604 ,Train_Loss: 0.3609,Valid_loss: 0.5942
# Time: 123.71177744865417sec
# Epoch [17/100],i_batch=604 ,Train_Loss: 0.1436,Valid_loss: 0.5757
# Time: 122.81065106391907sec
# Epoch [18/100],i_batch=604 ,Train_Loss: 0.3406,Valid_loss: 0.5689
# Time: 127.2102415561676sec
# Epoch [19/100],i_batch=604 ,Train_Loss: 0.2318,Valid_loss: 0.5633
# Time: 121.35654783248901sec
# Epoch [20/100],i_batch=604 ,Train_Loss: 0.2287,Valid_loss: 0.5684
# Time: 122.55343437194824sec
# Epoch [21/100],i_batch=604 ,Train_Loss: 0.0620,Valid_loss: 0.6089
# Time: 117.6561849117279sec
# Epoch [22/100],i_batch=604 ,Train_Loss: 0.3060,Valid_loss: 0.5440
# Time: 127.91681551933289sec
# Epoch [23/100],i_batch=604 ,Train_Loss: 0.2600,Valid_loss: 0.5823
# Time: 119.10252571105957sec
# Epoch [24/100],i_batch=604 ,Train_Loss: 0.1234,Valid_loss: 0.6512
# Time: 117.76400446891785sec
# Epoch [25/100],i_batch=604 ,Train_Loss: 0.0764,Valid_loss: 0.6078
# Time: 126.8478684425354sec
# Epoch [26/100],i_batch=604 ,Train_Loss: 0.3676,Valid_loss: 0.5400
# Time: 126.55653738975525sec
# Epoch [27/100],i_batch=604 ,Train_Loss: 0.0545,Valid_loss: 0.5562
# Time: 120.52079916000366sec
# Epoch [28/100],i_batch=604 ,Train_Loss: 0.3878,Valid_loss: 0.5913
# Time: 124.9383544921875sec
# Epoch [29/100],i_batch=604 ,Train_Loss: 0.2400,Valid_loss: 0.5835
# Time: 127.41413712501526sec
# Epoch [30/100],i_batch=604 ,Train_Loss: 0.3694,Valid_loss: 0.5505
# Time: 120.72977352142334sec
# Epoch [31/100],i_batch=604 ,Train_Loss: 0.0868,Valid_loss: 0.5800
# Time: 125.48712468147278sec
# Epoch [32/100],i_batch=604 ,Train_Loss: 0.3605,Valid_loss: 0.5576
# Time: 121.67977547645569sec
# Epoch [33/100],i_batch=604 ,Train_Loss: 0.0479,Valid_loss: 0.5727
# Time: 128.9763205051422sec
# Epoch [34/100],i_batch=604 ,Train_Loss: 0.1555,Valid_loss: 0.6509
# Time: 128.56720066070557sec
# Epoch [35/100],i_batch=604 ,Train_Loss: 0.2588,Valid_loss: 0.5778
# Time: 124.35492825508118sec
# Epoch [36/100],i_batch=604 ,Train_Loss: 0.1140,Valid_loss: 0.5798
# Time: 121.20646572113037sec
# Epoch [37/100],i_batch=604 ,Train_Loss: 0.0996,Valid_loss: 0.6186
# Time: 129.81220483779907sec
# Epoch [38/100],i_batch=604 ,Train_Loss: 0.0470,Valid_loss: 0.6341
# Time: 121.11550045013428sec
# Epoch [39/100],i_batch=604 ,Train_Loss: 0.0518,Valid_loss: 0.6230
# Time: 121.82407474517822sec
# Epoch [40/100],i_batch=604 ,Train_Loss: 0.2184,Valid_loss: 0.6138
# Time: 123.29839777946472sec
# Epoch [41/100],i_batch=604 ,Train_Loss: 0.0866,Valid_loss: 0.6202
# Time: 124.74900460243225sec
# Epoch [42/100],i_batch=604 ,Train_Loss: 0.0617,Valid_loss: 0.6204
# Time: 124.95477652549744sec
# Epoch [43/100],i_batch=604 ,Train_Loss: 0.0289,Valid_loss: 0.6665
# Time: 145.11163473129272sec
# Epoch [44/100],i_batch=604 ,Train_Loss: 0.2635,Valid_loss: 0.6331
# Time: 122.51221179962158sec
# Epoch [45/100],i_batch=604 ,Train_Loss: 0.1163,Valid_loss: 0.6168
# Time: 125.87241792678833sec
# Epoch [46/100],i_batch=604 ,Train_Loss: 0.2941,Valid_loss: 0.6192
# Time: 124.58427786827087sec
# Epoch [47/100],i_batch=604 ,Train_Loss: 0.0667,Valid_loss: 0.6448
# Time: 123.969810962677sec
# Epoch [48/100],i_batch=604 ,Train_Loss: 0.1163,Valid_loss: 0.6791
# Time: 113.74051690101624sec
# Epoch [49/100],i_batch=604 ,Train_Loss: 0.1492,Valid_loss: 0.6872
# Time: 80.53858971595764sec
# Epoch [50/100],i_batch=604 ,Train_Loss: 0.0632,Valid_loss: 0.6070
# Time: 80.59706497192383sec
# Epoch [51/100],i_batch=604 ,Train_Loss: 0.0289,Valid_loss: 0.6725
# Time: 80.32922959327698sec
# Epoch [52/100],i_batch=604 ,Train_Loss: 0.0587,Valid_loss: 0.6933
# Time: 80.6933045387268sec
# Epoch [53/100],i_batch=604 ,Train_Loss: 0.0981,Valid_loss: 0.6520
# Time: 80.72693228721619sec
# Epoch [54/100],i_batch=604 ,Train_Loss: 0.0872,Valid_loss: 0.6255
# Time: 80.91130661964417sec
# Epoch [55/100],i_batch=604 ,Train_Loss: 0.1075,Valid_loss: 0.6829
# Time: 81.1527452468872sec
# Epoch [56/100],i_batch=604 ,Train_Loss: 0.0919,Valid_loss: 0.6156
# Time: 80.70037150382996sec
# Epoch [57/100],i_batch=604 ,Train_Loss: 0.0805,Valid_loss: 0.6696
# Time: 80.6374499797821sec
# Epoch [58/100],i_batch=604 ,Train_Loss: 0.1255,Valid_loss: 0.6525
# Time: 80.72245144844055sec
# Epoch [59/100],i_batch=604 ,Train_Loss: 0.4338,Valid_loss: 0.6931
# Time: 80.85213232040405sec
# Epoch [60/100],i_batch=604 ,Train_Loss: 0.1048,Valid_loss: 0.6584
# Time: 80.86979556083679sec
# Epoch [61/100],i_batch=604 ,Train_Loss: 0.0324,Valid_loss: 0.7024
# Time: 81.13907837867737sec
# Epoch [62/100],i_batch=604 ,Train_Loss: 0.0923,Valid_loss: 0.6633
# Time: 80.86733627319336sec
# Epoch [63/100],i_batch=604 ,Train_Loss: 0.0182,Valid_loss: 0.7270
# Time: 81.11094117164612sec
# Epoch [64/100],i_batch=604 ,Train_Loss: 0.1353,Valid_loss: 0.6735
# Time: 81.11086964607239sec
# Epoch [65/100],i_batch=604 ,Train_Loss: 0.0468,Valid_loss: 0.7397
# Time: 80.98945474624634sec
# Epoch [66/100],i_batch=604 ,Train_Loss: 0.0177,Valid_loss: 0.6708
# Time: 80.60117697715759sec
# Epoch [67/100],i_batch=604 ,Train_Loss: 0.0332,Valid_loss: 0.6622
# Time: 81.03494215011597sec
# Epoch [68/100],i_batch=604 ,Train_Loss: 0.1662,Valid_loss: 0.6556
# Time: 80.58089089393616sec
# Epoch [69/100],i_batch=604 ,Train_Loss: 0.6944,Valid_loss: 0.7277
# Time: 80.8087854385376sec
# Epoch [70/100],i_batch=604 ,Train_Loss: 0.0867,Valid_loss: 0.7300
# Time: 80.63025736808777sec
# Epoch [71/100],i_batch=604 ,Train_Loss: 0.0264,Valid_loss: 0.6751
# Time: 80.75741839408875sec
# Epoch [72/100],i_batch=604 ,Train_Loss: 0.0390,Valid_loss: 0.7324
# Time: 80.82819509506226sec
# Epoch [73/100],i_batch=604 ,Train_Loss: 0.0397,Valid_loss: 0.6981
# Time: 80.87538957595825sec
# Epoch [74/100],i_batch=604 ,Train_Loss: 0.0291,Valid_loss: 0.6803
# Time: 80.87517857551575sec
# Epoch [75/100],i_batch=604 ,Train_Loss: 0.0545,Valid_loss: 0.6581
# Time: 80.65937447547913sec
# Epoch [76/100],i_batch=604 ,Train_Loss: 0.0472,Valid_loss: 0.7090
# Time: 81.78280973434448sec
# Epoch [77/100],i_batch=604 ,Train_Loss: 0.2813,Valid_loss: 0.6728
# Time: 81.65229535102844sec
# Epoch [78/100],i_batch=604 ,Train_Loss: 0.0416,Valid_loss: 0.6872
# Time: 80.32692074775696sec
# Epoch [79/100],i_batch=604 ,Train_Loss: 0.0997,Valid_loss: 0.7332
# Time: 81.05769729614258sec
# Epoch [80/100],i_batch=604 ,Train_Loss: 0.2205,Valid_loss: 0.7804
# Time: 81.4267098903656sec
# Epoch [81/100],i_batch=604 ,Train_Loss: 0.0800,Valid_loss: 0.7292
# Time: 80.76342797279358sec
# Epoch [82/100],i_batch=604 ,Train_Loss: 0.1365,Valid_loss: 0.7309
# Time: 81.6223075389862sec
# Epoch [83/100],i_batch=604 ,Train_Loss: 0.0794,Valid_loss: 0.7576
# Time: 80.52230405807495sec
# Epoch [84/100],i_batch=604 ,Train_Loss: 0.0188,Valid_loss: 0.7022
# Time: 80.87420082092285sec
# Epoch [85/100],i_batch=604 ,Train_Loss: 0.1063,Valid_loss: 0.6464
# Time: 81.13371777534485sec
# Epoch [86/100],i_batch=604 ,Train_Loss: 0.0373,Valid_loss: 0.7077
# Time: 80.78097176551819sec
# Epoch [87/100],i_batch=604 ,Train_Loss: 0.0276,Valid_loss: 0.7182
# Time: 81.39223217964172sec
# Epoch [88/100],i_batch=604 ,Train_Loss: 0.0132,Valid_loss: 0.6317
# Time: 80.45513129234314sec
# Epoch [89/100],i_batch=604 ,Train_Loss: 0.0586,Valid_loss: 0.8113
# Time: 80.90822958946228sec
# Epoch [90/100],i_batch=604 ,Train_Loss: 0.0932,Valid_loss: 0.7681
# Time: 80.55827713012695sec
# Epoch [91/100],i_batch=604 ,Train_Loss: 0.0326,Valid_loss: 0.7287
# Time: 80.95313119888306sec
# Epoch [92/100],i_batch=604 ,Train_Loss: 0.0306,Valid_loss: 0.6524
# Time: 80.94507074356079sec
# Epoch [93/100],i_batch=604 ,Train_Loss: 0.0659,Valid_loss: 0.6907
# Time: 80.76673936843872sec
# Epoch [94/100],i_batch=604 ,Train_Loss: 0.0577,Valid_loss: 0.7546
# Time: 81.47572159767151sec
# Epoch [95/100],i_batch=604 ,Train_Loss: 0.2086,Valid_loss: 0.7379
# Time: 81.16612482070923sec
# Epoch [96/100],i_batch=604 ,Train_Loss: 0.0689,Valid_loss: 0.7795
# Time: 80.85572290420532sec
# Epoch [97/100],i_batch=604 ,Train_Loss: 0.2145,Valid_loss: 0.7221
# Time: 80.58585095405579sec
# Epoch [98/100],i_batch=604 ,Train_Loss: 0.1392,Valid_loss: 0.7188
# Time: 81.72348737716675sec
# Epoch [99/100],i_batch=604 ,Train_Loss: 0.1840,Valid_loss: 0.8088
# Time: 80.95256614685059sec
# Epoch [100/100],i_batch=604 ,Train_Loss: 0.0869,Valid_loss: 0.7575
# Time: 81.00912809371948sec

# %%
plt.plot(train_loss_history)
plt.plot(valid_loss_history)
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
import csv


with open("valid_dropout_minmax.csv", 'w') as file:
  writer = csv.writer(file)
  writer.writerow(valid_loss_history)

# %%
import csv


with open("train_dropout_minmax.csv", 'w') as file:
  writer = csv.writer(file)
  writer.writerow(train_loss_history)

# %%
true_label=[]
pred_label=[]

model=CustomConvNet().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=hyper_param_learning_rate)

checkpoint = torch.load('/home/sumins/workspace/model_check/model_dropout_minmax.pth')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
loss = checkpoint['loss']
print(epoch)
print(loss)
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for item in test_loader:
        npys = item['npy'].to(device)
        labels = item['label'].to(device)
        
        outputs =model(npys)
        _, predicted = torch.max(outputs.data, 1)
        true_label.extend(labels)
        pred_label.extend(predicted)
        total += len(labels)
        correct += (predicted == labels).sum().item()
        
    print('Test Accuracy of the model on the {} test images: {} %'.format(total, 100 * correct / total))
# Out:
# 3
# tensor(0.5472, device='cuda:0', requires_grad=True)
# Test Accuracy of the model on the 2897 test images: 62.68553676216776 %

# %%
true_labels=torch.tensor(true_label)
true_labels=true_labels.tolist()
pred_labels=torch.tensor(pred_label)
pred_labels=pred_labels.tolist()
print(classification_report(true_labels,pred_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.58      0.70      2155
#            1       0.38      0.75      0.51       742
#
#     accuracy                           0.63      2897
#    macro avg       0.63      0.67      0.60      2897
# weighted avg       0.75      0.63      0.65      2897

# %%
true_label1=[]
pred_label1=[]

model=CustomConvNet().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=hyper_param_learning_rate)

checkpoint = torch.load('/home/sumins/workspace/model_check/model_dropout_minmax.pth')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
loss = checkpoint['loss']
print(loss)
custom_model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for item in train_loader:
        npys = item['npy'].to(device)
        labels = item['label'].to(device)
        
        outputs =model(npys)
        _, predicted = torch.max(outputs.data, 1)
        true_label1.extend(labels)
        pred_label1.extend(predicted)
        total += len(labels)
        correct += (predicted == labels).sum().item()
        
    print('Test Accuracy of the model on the {} train images: {} %'.format(total, 100 * correct / total))
# Out:
# tensor(0.5472, device='cuda:0', requires_grad=True)
# Test Accuracy of the model on the 19310 train images: 79.16105644743656 %

# %%
true_labels1=torch.tensor(true_label1)
true_labels1=true_labels1.tolist()
pred_labels1=torch.tensor(pred_label1)
pred_labels1=pred_labels1.tolist()
print(classification_report(true_labels1,pred_labels1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.92      0.86     13062
#            1       0.75      0.53      0.62      6248
#
#     accuracy                           0.79     19310
#    macro avg       0.78      0.72      0.74     19310
# weighted avg       0.79      0.79      0.78     19310
