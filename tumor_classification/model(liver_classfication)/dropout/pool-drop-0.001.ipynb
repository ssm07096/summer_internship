# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  
os.environ["CUDA_VISIBLE_DEVICES"]="6"

# %%
import numpy as np
from matplotlib import pyplot as plt
import nibabel as nib
from PIL import Image
from matplotlib import pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
from sklearn.model_selection import train_test_split
import torchsummary
from torchvision import transforms
import time
from sklearn.metrics import classification_report

# %%
#파일이름 sort해서 list저장
data_path='/disk1/data_liverbound_noclip/'
name_list=os.listdir(data_path)

segmentation_data = [files[:-4] for files in name_list if files.startswith('segmentation')]
segmentation_data=list(set(segmentation_data))
segmentation_data.sort()
seg_data_test=[]
for i in range(30,45):
    seg_data_test.append(segmentation_data.pop(i))

volume_data=[files[:-4] for files in name_list if files.startswith('volume')]
volume_data=list(set(volume_data))
volume_data.sort()
vol_data_test=[]
for i in range(30,45):
    vol_data_test.append(volume_data.pop(i))

# %%
# all_labels=np.loadtxt('/home/sumins/workspace/liver_classification/all_labels.txt',dtype=int)
# all_labels=all_labels.tolist()

# %%
#npy를 slice별로 나누어 하나의 list저장
seg_list_train=[]
seg_list_test=[]
for file in segmentation_data:
    fname=os.path.basename(file)
    print(fname)
    img_array=np.load(data_path+fname+'.npy')
    
    #print(f'img_num: {img_array.shape}')
    
    if len(img_array.shape) == 3:
        nx, ny, nz = img_array.shape
        total_slices = img_array.shape[2]
        #print(total_slices)
        # iterate through slices
        for current_slice in range(0, total_slices):
            seg_list_train.append(img_array[:,:,current_slice]) 

for file in seg_data_test:
    fname=os.path.basename(file)
    print(fname)
    img_array=np.load(data_path+fname+'.npy')
    
    #print(f'img_num: {img_array.shape}')
    
    if len(img_array.shape) == 3:
        nx, ny, nz = img_array.shape
        total_slices = img_array.shape[2]
        print(total_slices)
        # iterate through slices
        for current_slice in range(0, total_slices):
            seg_list_test.append(img_array[:,:,current_slice]) 
#간 1, 병변 2, 나머지 0


vol_list_train=[]
vol_list_test=[]
for file in volume_data:
    fname=os.path.basename(file)
    print(fname)
    img_array=np.load(data_path+fname+'.npy')
    
    #print(f'img_num: {img_array.shape}')
    
    if len(img_array.shape) == 3:
        nx, ny, nz = img_array.shape
        total_slices = img_array.shape[2]
        # iterate through slices
        for current_slice in range(0, total_slices):
            vol_list_train.append(img_array[:,:,current_slice]) 
            
for file in vol_data_test:
    fname=os.path.basename(file)
    print(fname)
    img_array=np.load(data_path+fname+'.npy')
    
    #print(f'img_num: {img_array.shape}')
    
    if len(img_array.shape) == 3:
        nx, ny, nz = img_array.shape
        total_slices = img_array.shape[2]
        # iterate through slices
        for current_slice in range(0, total_slices):
            vol_list_test.append(img_array[:,:,current_slice])
# Out:
# segmentation-0
# segmentation-1
# segmentation-10
# segmentation-100
# segmentation-101
# segmentation-102
# segmentation-103
# segmentation-104
# segmentation-105
# segmentation-106
# segmentation-107
# segmentation-108
# segmentation-109
# segmentation-11
# segmentation-110
# segmentation-111
# segmentation-112
# segmentation-113
# segmentation-114
# segmentation-115
# segmentation-116
# segmentation-117
# segmentation-118
# segmentation-119
# segmentation-12
# segmentation-120
# segmentation-121
# segmentation-122
# segmentation-123
# segmentation-124
# segmentation-126
# segmentation-128
# segmentation-13
# segmentation-15
# segmentation-17
# segmentation-19
# segmentation-20
# segmentation-22
# segmentation-24
# segmentation-26
# segmentation-28
# segmentation-3
# segmentation-31
# segmentation-33
# segmentation-35
# segmentation-36
# segmentation-37
# segmentation-38
# segmentation-39
# segmentation-4
# segmentation-40
# segmentation-41
# segmentation-42
# segmentation-43
# segmentation-44
# segmentation-45
# segmentation-46
# segmentation-47
# segmentation-48
# segmentation-49
# segmentation-5
# segmentation-50
# segmentation-51
# segmentation-52
# segmentation-53
# segmentation-54
# segmentation-55
# segmentation-56
# segmentation-57
# segmentation-58
# segmentation-59
# segmentation-6
# segmentation-60
# segmentation-61
# segmentation-62
# segmentation-63
# segmentation-64
# segmentation-65
# segmentation-66
# segmentation-67
# segmentation-68
# segmentation-69
# segmentation-7
# segmentation-70
# segmentation-71
# segmentation-72
# segmentation-73
# segmentation-74
# segmentation-75
# segmentation-76
# segmentation-77
# segmentation-78
# segmentation-79
# segmentation-8
# segmentation-80
# segmentation-81
# segmentation-82
# segmentation-83
# segmentation-84
# segmentation-85
# segmentation-86
# segmentation-87
# segmentation-88
# segmentation-89
# segmentation-9
# segmentation-90
# segmentation-91
# segmentation-92
# segmentation-93
# segmentation-94
# segmentation-95
# segmentation-96
# segmentation-97
# segmentation-98
# segmentation-99
# segmentation-125
# 133
# segmentation-127
# 270
# segmentation-129
# 325
# segmentation-14
# 164
# segmentation-16
# 222
# segmentation-18
# 224
# segmentation-2
# 164
# segmentation-21
# 191
# segmentation-23
# 137
# segmentation-25
# 277
# segmentation-27
# 272
# segmentation-29
# 135
# segmentation-30
# 146
# segmentation-32
# 128
# segmentation-34
# 109
# volume-0
# volume-1
# volume-10
# volume-100
# volume-101
# volume-102
# volume-103
# volume-104
# volume-105
# volume-106
# volume-107
# volume-108
# volume-109
# volume-11
# volume-110
# volume-111
# volume-112
# volume-113
# volume-114
# volume-115
# volume-116
# volume-117
# volume-118
# volume-119
# volume-12
# volume-120
# volume-121
# volume-122
# volume-123
# volume-124
# volume-126
# volume-128
# volume-13
# volume-15
# volume-17
# volume-19
# volume-20
# volume-22
# volume-24
# volume-26
# volume-28
# volume-3
# volume-31
# volume-33
# volume-35
# volume-36
# volume-37
# volume-38
# volume-39
# volume-4
# volume-40
# volume-41
# volume-42
# volume-43
# volume-44
# volume-45
# volume-46
# volume-47
# volume-48
# volume-49
# volume-5
# volume-50
# volume-51
# volume-52
# volume-53
# volume-54
# volume-55
# volume-56
# volume-57
# volume-58
# volume-59
# volume-6
# volume-60
# volume-61
# volume-62
# volume-63
# volume-64
# volume-65
# volume-66
# volume-67
# volume-68
# volume-69
# volume-7
# volume-70
# volume-71
# volume-72
# volume-73
# volume-74
# volume-75
# volume-76
# volume-77
# volume-78
# volume-79
# volume-8
# volume-80
# volume-81
# volume-82
# volume-83
# volume-84
# volume-85
# volume-86
# volume-87
# volume-88
# volume-89
# volume-9
# volume-90
# volume-91
# volume-92
# volume-93
# volume-94
# volume-95
# volume-96
# volume-97
# volume-98
# volume-99
# volume-125
# volume-127
# volume-129
# volume-14
# volume-16
# volume-18
# volume-2
# volume-21
# volume-23
# volume-25
# volume-27
# volume-29
# volume-30
# volume-32
# volume-34

# %%
#label을 만들어 list에 저장
labels_train = []
labels_test=[]
for i in seg_list_test:
    if 2 in i:
        labels_test.append(1)
    else:
        labels_test.append(0)
        
for i in seg_list_train:
    if 2 in i:
        labels_train.append(1)
    else:
        labels_train.append(0)

# %%
def norm(nparray):
    # normalize scans to [0,1]
    _min = nparray.min()
    _max = nparray.max()
    nparray = nparray - _min
    nparray = nparray / (_max - _min)
    return nparray

def norm_zscore(nparray):
    # normalize 2d scands by mean and standard deviation
    mean = nparray.mean()
    std = nparray.std()    
    nparray = nparray - mean
    nparray /= std
    return nparray

# %%
WINDOW_MAX = 200
WINDOW_MIN = 0
GLOBAL_PIXEL_MEAN = 0.1

class CustomDataset(Dataset): 
  def __init__(self,volume_list,all_labels,transforms=None):
    self.volume_list=volume_list
    self.all_labels=all_labels
    self.length=len(all_labels)
    self.transforms=transforms


  def __len__(self):
    return self.length


  def __getitem__(self, idx):
    npy=self.volume_list[idx]

    npy[npy > WINDOW_MAX] = WINDOW_MAX
    npy[npy < WINDOW_MIN] = WINDOW_MIN
    
    npy = (npy - WINDOW_MIN) / (WINDOW_MAX - WINDOW_MIN)
    npy -= GLOBAL_PIXEL_MEAN
    
    if len(npy.shape)==2:
      npy=npy[:,:,np.newaxis].astype(dtype='float32')
    
    if self.transforms is not None:
      npy=self.transforms(npy)
    
    return{'npy':npy,'label':self.all_labels[idx]}

# %%
class CustomConvNet(nn.Module):
    def __init__(self):
        super(CustomConvNet, self).__init__() #상속받은 class에 접근하기 위함

        self.layer1 = self.conv_module(1, 16) #흑백사진은 inp
        self.layer2 = self.conv_module(16, 32)
        self.layer3 = self.conv_module(32, 64)
        self.layer4 = self.conv_module(64, 128)
        self.layer5 = self.conv_module(128, 256)
        self.gap = self.global_avg_pool(256, 2)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        out = self.gap(out)
        out = out.view(-1, 2)

        return out

    def conv_module(self, in_num, out_num):
        return nn.Sequential(
            nn.Conv2d(in_num, out_num, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(out_num),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.4))

    def global_avg_pool(self, in_num, out_num):
        return nn.Sequential(
            nn.Conv2d(in_num, out_num, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(out_num),
            nn.LeakyReLU(),
            nn.AdaptiveAvgPool2d((1,1)))
        
model=CustomConvNet()
torchsummary.summary(model.cuda(),input_size=(1,512,512),batch_size=1)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [1, 16, 512, 512]             160
#        BatchNorm2d-2          [1, 16, 512, 512]              32
#          LeakyReLU-3          [1, 16, 512, 512]               0
#          MaxPool2d-4          [1, 16, 256, 256]               0
#            Dropout-5          [1, 16, 256, 256]               0
#             Conv2d-6          [1, 32, 256, 256]           4,640
#        BatchNorm2d-7          [1, 32, 256, 256]              64
#          LeakyReLU-8          [1, 32, 256, 256]               0
#          MaxPool2d-9          [1, 32, 128, 128]               0
#           Dropout-10          [1, 32, 128, 128]               0
#            Conv2d-11          [1, 64, 128, 128]          18,496
#       BatchNorm2d-12          [1, 64, 128, 128]             128
#         LeakyReLU-13          [1, 64, 128, 128]               0
#         MaxPool2d-14            [1, 64, 64, 64]               0
#           Dropout-15            [1, 64, 64, 64]               0
#            Conv2d-16           [1, 128, 64, 64]          73,856
#       BatchNorm2d-17           [1, 128, 64, 64]             256
#         LeakyReLU-18           [1, 128, 64, 64]               0
#         MaxPool2d-19           [1, 128, 32, 32]               0
#           Dropout-20           [1, 128, 32, 32]               0
#            Conv2d-21           [1, 256, 32, 32]         295,168
#       BatchNorm2d-22           [1, 256, 32, 32]             512
#         LeakyReLU-23           [1, 256, 32, 32]               0
#         MaxPool2d-24           [1, 256, 16, 16]               0
#           Dropout-25           [1, 256, 16, 16]               0
#            Conv2d-26             [1, 2, 16, 16]           4,610
#       BatchNorm2d-27             [1, 2, 16, 16]               4
#         LeakyReLU-28             [1, 2, 16, 16]               0
# AdaptiveAvgPool2d-29               [1, 2, 1, 1]               0
# ================================================================
# Total params: 397,926
# Trainable params: 397,926
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 1.00
# Forward/backward pass size (MB): 217.01
# Params size (MB): 1.52
# Estimated Total Size (MB): 219.53
# ----------------------------------------------------------------

# %%
transforms_train = transforms.Compose([transforms.ToTensor()
                                       ])
transforms_test = transforms.Compose([transforms.ToTensor()
                                       ])

hyper_param_epoch=100
hyper_param_batch=32
hyper_param_learning_rate=0.001

# %%
#vol_train, vol_valid, lab_train, lab_valid = train_test_split(volume_list, all_labels, test_size=0.3, shuffle=True, stratify=all_labels, random_state=34)
train_dataset=CustomDataset(volume_list=vol_list_train, all_labels=labels_train,transforms=transforms_train)
test_dataset=CustomDataset(volume_list=vol_list_test,all_labels=labels_test,transforms=transforms_test)
train_loader = DataLoader(train_dataset, batch_size=hyper_param_batch, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=hyper_param_batch, shuffle=True)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device,"/" ,torch.cuda.device_count())

custom_model=CustomConvNet().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(custom_model.parameters(), lr=hyper_param_learning_rate)
# Out:
# cuda:0 / 1

# %%
def validation_loss(model):
    total_loss=0
    for i_batch, item in enumerate(test_loader):
        npys = item['npy'].to(device)
        labels = item['label'].to(device)
 
        outputs =model(npys)
        loss = criterion(outputs, labels)

        total_loss+=loss.item()
    return total_loss/(i_batch+1)

# %%
loss_value=1
start=time.time()
custom_model.train()
train_loss_history=[]
valid_loss_history=[]
val_loss=0
for e in range(hyper_param_epoch):
        for i_batch, item in enumerate(train_loader):
                npys = item['npy'].to(device)
                labels = item['label'].to(device)
                #print(npys)
                # Forward pass
                outputs =custom_model(npys)
                loss = criterion(outputs, labels)

                # Backward and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
        val_loss=validation_loss(custom_model)
        train_loss_history.append(loss.item())
        valid_loss_history.append(val_loss)
        print('Epoch [{}/{}],i_batch={} ,Train_Loss: {:.4f},Valid_loss: {:.4f}'
                                        .format(e + 1, hyper_param_epoch, i_batch+1, loss.item(),val_loss))
        print("Time: {}sec".format(time.time()-start))
        start=time.time()
        if loss_value>val_loss:
                loss_value=val_loss
                torch.save({
                'epoch': e,
                'model_state_dict': custom_model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': loss,
                }, '/home/sumins/workspace/model_check/model_dropout_new.pth')
# Out:
# Epoch [1/100],i_batch=604 ,Train_Loss: 0.5114,Valid_loss: 0.5531
# Time: 76.10543060302734sec
# Epoch [2/100],i_batch=604 ,Train_Loss: 0.4190,Valid_loss: 0.5334
# Time: 76.88931679725647sec
# Epoch [3/100],i_batch=604 ,Train_Loss: 0.4185,Valid_loss: 0.5426
# Time: 77.15637159347534sec
# Epoch [4/100],i_batch=604 ,Train_Loss: 0.5382,Valid_loss: 0.5535
# Time: 77.24237012863159sec
# Epoch [5/100],i_batch=604 ,Train_Loss: 0.4004,Valid_loss: 0.5321
# Time: 77.3413200378418sec
# Epoch [6/100],i_batch=604 ,Train_Loss: 0.4534,Valid_loss: 0.5825
# Time: 77.31979393959045sec
# Epoch [7/100],i_batch=604 ,Train_Loss: 0.4578,Valid_loss: 0.5452
# Time: 77.22911190986633sec
# Epoch [8/100],i_batch=604 ,Train_Loss: 0.3778,Valid_loss: 0.5618
# Time: 77.41290330886841sec
# Epoch [9/100],i_batch=604 ,Train_Loss: 0.2176,Valid_loss: 0.5577
# Time: 77.24582004547119sec
# Epoch [10/100],i_batch=604 ,Train_Loss: 0.2559,Valid_loss: 0.5774
# Time: 77.1522753238678sec
# Epoch [11/100],i_batch=604 ,Train_Loss: 0.2875,Valid_loss: 0.5453
# Time: 77.20648550987244sec
# Epoch [12/100],i_batch=604 ,Train_Loss: 0.2158,Valid_loss: 0.5736
# Time: 77.20907592773438sec
# Epoch [13/100],i_batch=604 ,Train_Loss: 0.5286,Valid_loss: 0.5484
# Time: 77.1871268749237sec
# Epoch [14/100],i_batch=604 ,Train_Loss: 0.1792,Valid_loss: 0.5510
# Time: 77.19854998588562sec
# Epoch [15/100],i_batch=604 ,Train_Loss: 0.4057,Valid_loss: 0.5473
# Time: 77.38342261314392sec
# Epoch [16/100],i_batch=604 ,Train_Loss: 0.3061,Valid_loss: 0.5611
# Time: 77.20474314689636sec
# Epoch [17/100],i_batch=604 ,Train_Loss: 0.4085,Valid_loss: 0.5613
# Time: 77.36265683174133sec
# Epoch [18/100],i_batch=604 ,Train_Loss: 0.1476,Valid_loss: 0.5437
# Time: 77.43565964698792sec
# Epoch [19/100],i_batch=604 ,Train_Loss: 0.0848,Valid_loss: 0.5499
# Time: 77.1544988155365sec
# Epoch [20/100],i_batch=604 ,Train_Loss: 0.1032,Valid_loss: 0.5272
# Time: 77.13474249839783sec
# Epoch [21/100],i_batch=604 ,Train_Loss: 0.1805,Valid_loss: 0.6357
# Time: 77.29493713378906sec
# Epoch [22/100],i_batch=604 ,Train_Loss: 0.0741,Valid_loss: 0.5711
# Time: 77.18234515190125sec
# Epoch [23/100],i_batch=604 ,Train_Loss: 0.3310,Valid_loss: 0.5295
# Time: 77.08274388313293sec
# Epoch [24/100],i_batch=604 ,Train_Loss: 0.2279,Valid_loss: 0.6185
# Time: 76.95829892158508sec
# Epoch [25/100],i_batch=604 ,Train_Loss: 0.1539,Valid_loss: 0.6002
# Time: 77.82659125328064sec
# Epoch [26/100],i_batch=604 ,Train_Loss: 0.2484,Valid_loss: 0.6041
# Time: 77.21839690208435sec
# Epoch [27/100],i_batch=604 ,Train_Loss: 0.1459,Valid_loss: 0.5511
# Time: 77.68901872634888sec
# Epoch [28/100],i_batch=604 ,Train_Loss: 0.0647,Valid_loss: 0.6075
# Time: 77.02532076835632sec
# Epoch [29/100],i_batch=604 ,Train_Loss: 0.0488,Valid_loss: 0.5477
# Time: 77.99533414840698sec
# Epoch [30/100],i_batch=604 ,Train_Loss: 0.1453,Valid_loss: 0.5636
# Time: 77.11217784881592sec
# Epoch [31/100],i_batch=604 ,Train_Loss: 0.1180,Valid_loss: 0.5648
# Time: 76.62421607971191sec
# Epoch [32/100],i_batch=604 ,Train_Loss: 0.0410,Valid_loss: 0.5739
# Time: 76.83143353462219sec
# Epoch [33/100],i_batch=604 ,Train_Loss: 0.1266,Valid_loss: 0.6347
# Time: 76.90095543861389sec
# Epoch [34/100],i_batch=604 ,Train_Loss: 0.0869,Valid_loss: 0.6108
# Time: 76.85930824279785sec
# Epoch [35/100],i_batch=604 ,Train_Loss: 0.1012,Valid_loss: 0.5660
# Time: 77.03511643409729sec
# Epoch [36/100],i_batch=604 ,Train_Loss: 0.1155,Valid_loss: 0.6093
# Time: 77.83856177330017sec
# Epoch [37/100],i_batch=604 ,Train_Loss: 0.1178,Valid_loss: 0.6128
# Time: 77.63441109657288sec
# Epoch [38/100],i_batch=604 ,Train_Loss: 0.1964,Valid_loss: 0.6109
# Time: 77.67675924301147sec
# Epoch [39/100],i_batch=604 ,Train_Loss: 0.0681,Valid_loss: 0.5871
# Time: 77.59484720230103sec
# Epoch [40/100],i_batch=604 ,Train_Loss: 0.2947,Valid_loss: 0.6015
# Time: 77.44208979606628sec
# Epoch [41/100],i_batch=604 ,Train_Loss: 0.2425,Valid_loss: 0.5976
# Time: 79.17603397369385sec
# Epoch [42/100],i_batch=604 ,Train_Loss: 0.1293,Valid_loss: 0.5844
# Time: 78.21979284286499sec
# Epoch [43/100],i_batch=604 ,Train_Loss: 0.3141,Valid_loss: 0.5541
# Time: 78.1352424621582sec
# Epoch [44/100],i_batch=604 ,Train_Loss: 0.2396,Valid_loss: 0.6354
# Time: 136.84862112998962sec
# Epoch [45/100],i_batch=604 ,Train_Loss: 0.0710,Valid_loss: 0.6561
# Time: 236.70494437217712sec
# Epoch [46/100],i_batch=604 ,Train_Loss: 0.0141,Valid_loss: 0.6348
# Time: 209.775554895401sec
# Epoch [47/100],i_batch=604 ,Train_Loss: 0.0933,Valid_loss: 0.6490
# Time: 250.01541376113892sec
# Epoch [48/100],i_batch=604 ,Train_Loss: 0.0793,Valid_loss: 0.6422
# Time: 242.69556188583374sec
# Epoch [49/100],i_batch=604 ,Train_Loss: 0.0252,Valid_loss: 0.7205
# Time: 80.41294431686401sec
# Epoch [50/100],i_batch=604 ,Train_Loss: 0.0638,Valid_loss: 0.6523
# Time: 77.55312728881836sec
# Epoch [51/100],i_batch=604 ,Train_Loss: 0.1136,Valid_loss: 0.6749
# Time: 78.30331635475159sec
# Epoch [52/100],i_batch=604 ,Train_Loss: 0.1076,Valid_loss: 0.6288
# Time: 229.1023087501526sec
# Epoch [53/100],i_batch=604 ,Train_Loss: 0.1974,Valid_loss: 0.6682
# Time: 237.79482102394104sec
# Epoch [54/100],i_batch=604 ,Train_Loss: 0.3793,Valid_loss: 0.7135
# Time: 231.60673069953918sec
# Epoch [55/100],i_batch=604 ,Train_Loss: 0.0308,Valid_loss: 0.6620
# Time: 233.47470116615295sec
# Epoch [56/100],i_batch=604 ,Train_Loss: 0.2190,Valid_loss: 0.7106
# Time: 232.4426794052124sec
# Epoch [57/100],i_batch=604 ,Train_Loss: 0.0779,Valid_loss: 0.6110
# Time: 209.1801085472107sec
# Epoch [58/100],i_batch=604 ,Train_Loss: 0.2578,Valid_loss: 0.6452
# Time: 230.362646818161sec
# Epoch [59/100],i_batch=604 ,Train_Loss: 0.1807,Valid_loss: 0.6804
# Time: 210.28043007850647sec
# Epoch [60/100],i_batch=604 ,Train_Loss: 0.0326,Valid_loss: 0.6908
# Time: 213.4623703956604sec
# Epoch [61/100],i_batch=604 ,Train_Loss: 0.2019,Valid_loss: 0.6808
# Time: 205.8914430141449sec
# Epoch [62/100],i_batch=604 ,Train_Loss: 0.1980,Valid_loss: 0.7053
# Time: 223.88794112205505sec
# Epoch [63/100],i_batch=604 ,Train_Loss: 0.0163,Valid_loss: 0.6877
# Time: 200.369225025177sec
# Epoch [64/100],i_batch=604 ,Train_Loss: 0.1046,Valid_loss: 0.6298
# Time: 198.04290080070496sec
# Epoch [65/100],i_batch=604 ,Train_Loss: 0.0543,Valid_loss: 0.6324
# Time: 188.52519726753235sec
# Epoch [66/100],i_batch=604 ,Train_Loss: 0.0374,Valid_loss: 0.6719
# Time: 212.9342200756073sec
# Epoch [67/100],i_batch=604 ,Train_Loss: 0.0184,Valid_loss: 0.6640
# Time: 211.4185938835144sec
# Epoch [68/100],i_batch=604 ,Train_Loss: 0.0115,Valid_loss: 0.6717
# Time: 207.94146847724915sec
# Epoch [69/100],i_batch=604 ,Train_Loss: 0.4198,Valid_loss: 0.7060
# Time: 211.8112232685089sec
# Epoch [70/100],i_batch=604 ,Train_Loss: 0.0092,Valid_loss: 0.7137
# Time: 195.7860655784607sec
# Epoch [71/100],i_batch=604 ,Train_Loss: 0.2941,Valid_loss: 0.6598
# Time: 211.57930397987366sec
# Epoch [72/100],i_batch=604 ,Train_Loss: 0.0486,Valid_loss: 0.7225
# Time: 209.88509607315063sec
# Epoch [73/100],i_batch=604 ,Train_Loss: 0.1137,Valid_loss: 0.7126
# Time: 222.04779720306396sec
# Epoch [74/100],i_batch=604 ,Train_Loss: 0.0196,Valid_loss: 0.6950
# Time: 209.88932585716248sec
# Epoch [75/100],i_batch=604 ,Train_Loss: 0.2375,Valid_loss: 0.6858
# Time: 215.94418954849243sec
# Epoch [76/100],i_batch=604 ,Train_Loss: 0.1309,Valid_loss: 0.6809
# Time: 200.99830412864685sec
# Epoch [77/100],i_batch=604 ,Train_Loss: 0.1133,Valid_loss: 0.7043
# Time: 200.15042853355408sec
# Epoch [78/100],i_batch=604 ,Train_Loss: 0.0226,Valid_loss: 0.7243
# Time: 214.243825674057sec
# Epoch [79/100],i_batch=604 ,Train_Loss: 0.6283,Valid_loss: 0.7092
# Time: 235.06414198875427sec
# Epoch [80/100],i_batch=604 ,Train_Loss: 0.0533,Valid_loss: 0.6510
# Time: 190.18884325027466sec
# Epoch [81/100],i_batch=604 ,Train_Loss: 0.1727,Valid_loss: 0.7590
# Time: 196.95507907867432sec
# Epoch [82/100],i_batch=604 ,Train_Loss: 0.2599,Valid_loss: 0.6738
# Time: 199.18549466133118sec
# Epoch [83/100],i_batch=604 ,Train_Loss: 0.0637,Valid_loss: 0.7212
# Time: 201.20254015922546sec
# Epoch [84/100],i_batch=604 ,Train_Loss: 0.0600,Valid_loss: 0.7296
# Time: 212.33587265014648sec
# Epoch [85/100],i_batch=604 ,Train_Loss: 0.0252,Valid_loss: 0.7029
# Time: 219.1626739501953sec
# Epoch [86/100],i_batch=604 ,Train_Loss: 0.0509,Valid_loss: 0.7420
# Time: 198.1517403125763sec
# Epoch [87/100],i_batch=604 ,Train_Loss: 0.1106,Valid_loss: 0.7140
# Time: 208.38050866127014sec
# Epoch [88/100],i_batch=604 ,Train_Loss: 0.3037,Valid_loss: 0.7425
# Time: 207.3712944984436sec
# Epoch [89/100],i_batch=604 ,Train_Loss: 0.0364,Valid_loss: 0.6877
# Time: 179.58996725082397sec
# Epoch [90/100],i_batch=604 ,Train_Loss: 0.2398,Valid_loss: 0.7186
# Time: 200.81568670272827sec
# Epoch [91/100],i_batch=604 ,Train_Loss: 0.0126,Valid_loss: 0.7270
# Time: 193.99945521354675sec
# Epoch [92/100],i_batch=604 ,Train_Loss: 0.0907,Valid_loss: 0.7756
# Time: 207.9631838798523sec
# Epoch [93/100],i_batch=604 ,Train_Loss: 0.0041,Valid_loss: 0.7827
# Time: 183.6670229434967sec
# Epoch [94/100],i_batch=604 ,Train_Loss: 0.0783,Valid_loss: 0.7111
# Time: 203.44895005226135sec
# Epoch [95/100],i_batch=604 ,Train_Loss: 0.0085,Valid_loss: 0.7557
# Time: 193.54417395591736sec
# Epoch [96/100],i_batch=604 ,Train_Loss: 0.0755,Valid_loss: 0.7916
# Time: 204.8039586544037sec
# Epoch [97/100],i_batch=604 ,Train_Loss: 0.2303,Valid_loss: 0.7206
# Time: 192.54600834846497sec
# Epoch [98/100],i_batch=604 ,Train_Loss: 0.0168,Valid_loss: 0.7163
# Time: 225.44839906692505sec
# Epoch [99/100],i_batch=604 ,Train_Loss: 0.0649,Valid_loss: 0.7663
# Time: 262.8531165122986sec
# Epoch [100/100],i_batch=604 ,Train_Loss: 0.0477,Valid_loss: 0.7679
# Time: 221.3516366481781sec

# %%
plt.plot(train_loss_history)
plt.plot(valid_loss_history)
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
import csv


with open("valid_loss_history_dropout.csv", 'w') as file:
  writer = csv.writer(file)
  writer.writerow(valid_loss_history)

# %%
import csv


with open("train_loss_history_dropout.csv", 'w') as file:
  writer = csv.writer(file)
  writer.writerow(train_loss_history)

# %%
true_label=[]
pred_label=[]

model=CustomConvNet().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=hyper_param_learning_rate)

checkpoint = torch.load('/home/sumins/workspace/model_check/model_dropout_new.pth')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
loss = checkpoint['loss']
print(epoch)
print(loss)
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for item in test_loader:
        npys = item['npy'].to(device)
        labels = item['label'].to(device)
        
        outputs =model(npys)
        _, predicted = torch.max(outputs.data, 1)
        true_label.extend(labels)
        pred_label.extend(predicted)
        total += len(labels)
        correct += (predicted == labels).sum().item()
        
    print('Test Accuracy of the model on the {} test images: {} %'.format(total, 100 * correct / total))
# Out:
# 19
# tensor(0.1032, device='cuda:0', requires_grad=True)
# Test Accuracy of the model on the 2897 test images: 71.69485674836038 %

# %%
true_labels=torch.tensor(true_label)
true_labels=true_labels.tolist()
pred_labels=torch.tensor(pred_label)
pred_labels=pred_labels.tolist()
print(classification_report(true_labels,pred_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.74      0.80      2155
#            1       0.46      0.64      0.54       742
#
#     accuracy                           0.72      2897
#    macro avg       0.66      0.69      0.67      2897
# weighted avg       0.76      0.72      0.73      2897

# %%
true_label1=[]
pred_label1=[]

model=CustomConvNet().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=hyper_param_learning_rate)

checkpoint = torch.load('/home/sumins/workspace/model_check/model_dropout_new.pth')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
loss = checkpoint['loss']
print(loss)
custom_model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for item in train_loader:
        npys = item['npy'].to(device)
        labels = item['label'].to(device)
        
        outputs =model(npys)
        _, predicted = torch.max(outputs.data, 1)
        true_label1.extend(labels)
        pred_label1.extend(predicted)
        total += len(labels)
        correct += (predicted == labels).sum().item()
        
    print('Test Accuracy of the model on the {} train images: {} %'.format(total, 100 * correct / total))
# Out:
# tensor(0.1032, device='cuda:0', requires_grad=True)
# Test Accuracy of the model on the 19310 train images: 92.92594510616262 %

# %%
true_labels1=torch.tensor(true_label1)
true_labels1=true_labels1.tolist()
pred_labels1=torch.tensor(pred_label1)
pred_labels1=pred_labels1.tolist()
print(classification_report(true_labels1,pred_labels1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95     13062
#            1       0.92      0.86      0.89      6248
#
#     accuracy                           0.93     19310
#    macro avg       0.93      0.91      0.92     19310
# weighted avg       0.93      0.93      0.93     19310
