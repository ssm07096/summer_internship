# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  
os.environ["CUDA_VISIBLE_DEVICES"]="6"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4835cb1f5617> in <module>
# ----> 1 import osfff
#       2 os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
#       3 os.environ["CUDA_VISIBLE_DEVICES"]="6"
#
# ModuleNotFoundError: No module named 'osfff'

# %%
import numpy as np
from matplotlib import pyplot as plt
import nibabel as nib
from PIL import Image
from matplotlib import pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from torch import nn
import torchsummary
from torchvision import transforms
import time
from sklearn.metrics import classification_report

# %%
label_data=np.loadtxt('/home/sumins/workspace/washout classification/2phase_min_slice/label_train.txt',dtype=int)
label_data=label_data.tolist()
label_datat=np.loadtxt('/home/sumins/workspace/washout classification/2phase_min_slice/label_test.txt',dtype=int)
label_datat=label_datat.tolist()

# %%
data_path='/home/sumins/workspace/washout classification/2phase_min_slice/channel4_train.nii'
channel4=[]
total=nib.load(data_path).get_fdata()
totalslice=total.shape[0]  

for i in range(0,totalslice):
    channel4.append(total[i,:,:,:])


data_patht='/home/sumins/workspace/washout classification/2phase_min_slice/channel4_test.nii'
channel4t=[]
totalt=nib.load(data_patht).get_fdata()
totalslicet=totalt.shape[0]  

for i in range(0,totalslicet):
    channel4t.append(totalt[i,:,:,:])

# %%
WINDOW_MAX = 200
WINDOW_MIN = 0
GLOBAL_PIXEL_MEAN = 0.1

class CustomDataset(Dataset): 
  def __init__(self,volume_list,all_labels,transforms=None):
    self.volume_list=volume_list
    self.all_labels=all_labels
    self.length=len(all_labels)
    self.transforms=transforms


  def __len__(self):
    return self.length


  def __getitem__(self, idx):
    npy=self.volume_list[idx]

    npy[npy > WINDOW_MAX] = WINDOW_MAX
    npy[npy < WINDOW_MIN] = WINDOW_MIN
    
    npy = (npy - WINDOW_MIN) / (WINDOW_MAX - WINDOW_MIN)
    npy -= GLOBAL_PIXEL_MEAN
    
    npy=npy.astype(dtype='float32')
    if self.transforms is not None:
      npy=self.transforms(npy)
    
    return{'npy':npy,'label':self.all_labels[idx]}

# %%
transforms_train = transforms.Compose([transforms.ToTensor()
                                       ])
transforms_test = transforms.Compose([transforms.ToTensor()
                                       ])

# %%
class CustomConvNet(nn.Module):
    def __init__(self):
        super(CustomConvNet, self).__init__() #상속받은 class에 접근하기 위함

        self.layer1 = self.conv_module(2, 16) #흑백사진은 inp
        self.layer2 = self.conv_module(16, 32)
        self.layer3 = self.conv_module(32, 64)
        self.layer4 = self.conv_module(64, 128)
        self.layer5 = self.conv_module(128, 256)
        self.gap = self.global_avg_pool(256, 2)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        out = self.gap(out)
        out = out.view(-1, 2)

        return out

    def conv_module(self, in_num, out_num):
        return nn.Sequential(
            nn.Conv2d(in_num, out_num, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(out_num),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
            )

    def global_avg_pool(self, in_num, out_num):
        return nn.Sequential(
            nn.Conv2d(in_num, out_num, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(out_num),
            nn.LeakyReLU(),
            nn.AdaptiveAvgPool2d((1,1)))
        
model=CustomConvNet()
torchsummary.summary(model.cuda(),input_size=(2,512,512),batch_size=4)

# %%
hyper_param_epoch=200
hyper_param_batch=8
hyper_param_learning_rate=0.0001

# %%
print(len(channel4))
print(len(channel4t))

# %%
train_dataset=CustomDataset(volume_list=channel4, all_labels=label_data,transforms=transforms_train)
train_loader = DataLoader(train_dataset, batch_size=hyper_param_batch, shuffle=True)
test_dataset=CustomDataset(volume_list=channel4t, all_labels=label_datat,transforms=transforms_train)
test_loader = DataLoader(test_dataset, batch_size=hyper_param_batch, shuffle=True)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device,"/" ,torch.cuda.device_count())

custom_model=CustomConvNet().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(custom_model.parameters(), lr=hyper_param_learning_rate)

# %%
def validation_loss(model):
    total_loss=0
    for i_batch, item in enumerate(test_loader):
        npys = item['npy'].to(device)
        labels = item['label'].to(device)
 
        outputs =model(npys)
        loss = criterion(outputs, labels)

        total_loss+=loss.item()
    return total_loss/(i_batch+1)

# %%
loss_value=1
start=time.time()
custom_model.train()
train_loss_history=[]
valid_loss_history=[]
val_loss=0
for e in range(hyper_param_epoch):
        for i_batch, item in enumerate(train_loader):
                npys = item['npy'].to(device)
                labels = item['label'].to(device)
                #print(npys)
                # Forward pass
                outputs =custom_model(npys)
                loss = criterion(outputs, labels)

                # Backward and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
        val_loss=validation_loss(custom_model)
        train_loss_history.append(loss.item())
        valid_loss_history.append(val_loss)
        print('Epoch [{}/{}],i_batch={} ,Train_Loss: {:.4f},Valid_loss: {:.4f}'
                                        .format(e + 1, hyper_param_epoch, i_batch+1, loss.item(),val_loss))
        print("Time: {}sec".format(time.time()-start))
        start=time.time()
        if loss_value>val_loss:
                loss_value=val_loss
                torch.save({
                'epoch': e,
                'model_state_dict': custom_model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': loss,
                }, '/home/sumins/workspace/washout classification/model_save/model5.pth')
# Out:
# Epoch [50/200],i_batch=178 ,Train_Loss: 0.1982,Valid_loss: 0.6565
# Time: 94.2775547504425sec
# Epoch [51/200],i_batch=178 ,Train_Loss: 0.2406,Valid_loss: 0.6665
# Time: 120.73581647872925sec
# Epoch [52/200],i_batch=178 ,Train_Loss: 0.1763,Valid_loss: 0.6302
# Time: 129.94051384925842sec
# Epoch [53/200],i_batch=178 ,Train_Loss: 0.2274,Valid_loss: 0.6569
# Time: 106.74023199081421sec
# Epoch [54/200],i_batch=178 ,Train_Loss: 0.1957,Valid_loss: 0.6143
# Time: 106.81838703155518sec
# Epoch [55/200],i_batch=178 ,Train_Loss: 0.1745,Valid_loss: 0.6393
# Time: 118.62200808525085sec
# Epoch [56/200],i_batch=178 ,Train_Loss: 0.3106,Valid_loss: 0.6630
# Time: 139.62237119674683sec
# Epoch [57/200],i_batch=178 ,Train_Loss: 0.1594,Valid_loss: 0.6373
# Time: 134.41444849967957sec
# Epoch [58/200],i_batch=178 ,Train_Loss: 0.3081,Valid_loss: 0.6349
# Time: 115.01016306877136sec
# Epoch [59/200],i_batch=178 ,Train_Loss: 0.1996,Valid_loss: 0.6400
# Time: 117.9563455581665sec
# Epoch [60/200],i_batch=178 ,Train_Loss: 0.1693,Valid_loss: 0.6542
# Time: 154.11684560775757sec
# Epoch [61/200],i_batch=178 ,Train_Loss: 0.1638,Valid_loss: 0.6472
# Time: 134.40982007980347sec
# Epoch [62/200],i_batch=178 ,Train_Loss: 0.1459,Valid_loss: 0.6205
# Time: 100.84526205062866sec
# Epoch [63/200],i_batch=178 ,Train_Loss: 0.1565,Valid_loss: 0.6491
# Time: 89.53384566307068sec
# Epoch [64/200],i_batch=178 ,Train_Loss: 0.1575,Valid_loss: 0.6440
# Time: 97.15041732788086sec
# Epoch [65/200],i_batch=178 ,Train_Loss: 0.1524,Valid_loss: 0.6498
# Time: 88.54698848724365sec
# Epoch [66/200],i_batch=178 ,Train_Loss: 0.1517,Valid_loss: 0.6722
# Time: 94.39455223083496sec
# Epoch [67/200],i_batch=178 ,Train_Loss: 0.1370,Valid_loss: 0.6452
# Time: 98.3854820728302sec
# Epoch [68/200],i_batch=178 ,Train_Loss: 0.1319,Valid_loss: 0.6379
# Time: 104.31876730918884sec
# Epoch [69/200],i_batch=178 ,Train_Loss: 0.1521,Valid_loss: 0.6725
# Time: 94.13383173942566sec
# Epoch [70/200],i_batch=178 ,Train_Loss: 0.1331,Valid_loss: 0.6518
# Time: 92.00925803184509sec
# Epoch [71/200],i_batch=178 ,Train_Loss: 0.1214,Valid_loss: 0.7003
# Time: 106.00240850448608sec
# Epoch [72/200],i_batch=178 ,Train_Loss: 0.1835,Valid_loss: 0.6646
# Time: 111.27809643745422sec
# Epoch [73/200],i_batch=178 ,Train_Loss: 0.1242,Valid_loss: 0.6718
# Time: 103.93405222892761sec
# Epoch [74/200],i_batch=178 ,Train_Loss: 0.1582,Valid_loss: 0.6753
# Time: 111.2550311088562sec
# Epoch [75/200],i_batch=178 ,Train_Loss: 0.2834,Valid_loss: 0.6731
# Time: 110.2879683971405sec
# Epoch [76/200],i_batch=178 ,Train_Loss: 0.1141,Valid_loss: 0.6795
# Time: 147.61275577545166sec
# Epoch [77/200],i_batch=178 ,Train_Loss: 0.1149,Valid_loss: 0.6565
# Time: 136.69920825958252sec
# Epoch [78/200],i_batch=178 ,Train_Loss: 0.2641,Valid_loss: 0.6602
# Time: 129.94752264022827sec
# Epoch [79/200],i_batch=178 ,Train_Loss: 0.2405,Valid_loss: 0.6628
# Time: 136.01016116142273sec
# Epoch [80/200],i_batch=178 ,Train_Loss: 0.2317,Valid_loss: 0.6404
# Time: 135.88130950927734sec
# Epoch [81/200],i_batch=178 ,Train_Loss: 0.1095,Valid_loss: 0.6639
# Time: 137.90451836585999sec
# Epoch [82/200],i_batch=178 ,Train_Loss: 0.1027,Valid_loss: 0.6772
# Time: 153.34087944030762sec
# Epoch [83/200],i_batch=178 ,Train_Loss: 0.2492,Valid_loss: 0.7006
# Time: 156.23910117149353sec
# Epoch [84/200],i_batch=178 ,Train_Loss: 0.1051,Valid_loss: 0.6679
# Time: 159.85855150222778sec
# Epoch [85/200],i_batch=178 ,Train_Loss: 0.1000,Valid_loss: 0.6482
# Time: 158.55037093162537sec
# Epoch [86/200],i_batch=178 ,Train_Loss: 0.1046,Valid_loss: 0.6690
# Time: 251.81595396995544sec
# Epoch [87/200],i_batch=178 ,Train_Loss: 0.1005,Valid_loss: 0.6462
# Time: 283.91707468032837sec
# Epoch [88/200],i_batch=178 ,Train_Loss: 0.2316,Valid_loss: 0.6654
# Time: 276.2925419807434sec
# Epoch [89/200],i_batch=178 ,Train_Loss: 0.0925,Valid_loss: 0.6626
# Time: 289.17848467826843sec
# Epoch [90/200],i_batch=178 ,Train_Loss: 0.1018,Valid_loss: 0.6594
# Time: 290.6637706756592sec
# Epoch [91/200],i_batch=178 ,Train_Loss: 0.0879,Valid_loss: 0.6867
# Time: 263.1222331523895sec
# Epoch [92/200],i_batch=178 ,Train_Loss: 0.0948,Valid_loss: 0.6821
# Time: 160.82772707939148sec
# Epoch [93/200],i_batch=178 ,Train_Loss: 0.0912,Valid_loss: 0.7328
# Time: 164.56600046157837sec
# Epoch [94/200],i_batch=178 ,Train_Loss: 0.0871,Valid_loss: 0.7020
# Time: 155.46675419807434sec
# Epoch [95/200],i_batch=178 ,Train_Loss: 0.0953,Valid_loss: 0.6769
# Time: 160.10497188568115sec
# Epoch [96/200],i_batch=178 ,Train_Loss: 0.0814,Valid_loss: 0.6880
# Time: 150.93705129623413sec
# Epoch [97/200],i_batch=178 ,Train_Loss: 0.0826,Valid_loss: 0.6823
# Time: 144.75705194473267sec
# Epoch [98/200],i_batch=178 ,Train_Loss: 0.0774,Valid_loss: 0.6572
# Time: 206.02557921409607sec
# Epoch [99/200],i_batch=178 ,Train_Loss: 0.0769,Valid_loss: 0.6828
# Time: 256.8039593696594sec
# Epoch [100/200],i_batch=178 ,Train_Loss: 0.0758,Valid_loss: 0.6704
# Time: 276.44117641448975sec
# Epoch [101/200],i_batch=178 ,Train_Loss: 0.0798,Valid_loss: 0.6770
# Time: 272.47512674331665sec
# Epoch [102/200],i_batch=178 ,Train_Loss: 0.5482,Valid_loss: 0.7024
# Time: 264.607275724411sec
# Epoch [103/200],i_batch=178 ,Train_Loss: 0.0790,Valid_loss: 0.6740
# Time: 190.3844861984253sec
# Epoch [104/200],i_batch=178 ,Train_Loss: 0.1236,Valid_loss: 0.7024
# Time: 134.95897483825684sec
# Epoch [105/200],i_batch=178 ,Train_Loss: 0.2435,Valid_loss: 0.6803
# Time: 133.1450207233429sec
# Epoch [106/200],i_batch=178 ,Train_Loss: 0.0666,Valid_loss: 0.7268
# Time: 132.72159886360168sec
# Epoch [107/200],i_batch=178 ,Train_Loss: 0.0703,Valid_loss: 0.7187
# Time: 133.10202169418335sec
# Epoch [108/200],i_batch=178 ,Train_Loss: 0.0820,Valid_loss: 0.7502
# Time: 111.34183645248413sec
# Epoch [109/200],i_batch=178 ,Train_Loss: 0.0747,Valid_loss: 0.7012
# Time: 105.37240195274353sec
# Epoch [110/200],i_batch=178 ,Train_Loss: 0.1110,Valid_loss: 0.6878
# Time: 101.12032198905945sec
# Epoch [111/200],i_batch=178 ,Train_Loss: 0.0774,Valid_loss: 0.6915
# Time: 90.80822014808655sec
# Epoch [112/200],i_batch=178 ,Train_Loss: 0.1688,Valid_loss: 0.7018
# Time: 91.41000485420227sec
# Epoch [113/200],i_batch=178 ,Train_Loss: 0.0912,Valid_loss: 0.7441
# Time: 102.99561786651611sec
# Epoch [114/200],i_batch=178 ,Train_Loss: 0.1774,Valid_loss: 0.7150
# Time: 104.12904572486877sec
# Epoch [115/200],i_batch=178 ,Train_Loss: 0.0625,Valid_loss: 0.7060
# Time: 106.41710305213928sec
# Epoch [116/200],i_batch=178 ,Train_Loss: 0.0697,Valid_loss: 0.7061
# Time: 128.46745443344116sec
# Epoch [117/200],i_batch=178 ,Train_Loss: 0.0684,Valid_loss: 0.7345
# Time: 127.10990071296692sec
# Epoch [118/200],i_batch=178 ,Train_Loss: 0.0606,Valid_loss: 0.7234
# Time: 123.05281209945679sec
# Epoch [119/200],i_batch=178 ,Train_Loss: 0.2548,Valid_loss: 0.6711
# Time: 124.37246417999268sec
# Epoch [120/200],i_batch=178 ,Train_Loss: 0.0629,Valid_loss: 0.7250
# Time: 125.06930184364319sec
# Epoch [121/200],i_batch=178 ,Train_Loss: 0.2092,Valid_loss: 0.7665
# Time: 133.73098301887512sec
# Epoch [122/200],i_batch=178 ,Train_Loss: 0.1585,Valid_loss: 0.6841
# Time: 131.15367603302002sec
# Epoch [123/200],i_batch=178 ,Train_Loss: 0.2174,Valid_loss: 0.7100
# Time: 133.7430784702301sec
# Epoch [124/200],i_batch=178 ,Train_Loss: 0.1046,Valid_loss: 0.7116
# Time: 133.80448126792908sec
# Epoch [125/200],i_batch=178 ,Train_Loss: 0.2611,Valid_loss: 0.7085
# Time: 133.12615132331848sec
# Epoch [126/200],i_batch=178 ,Train_Loss: 0.1116,Valid_loss: 0.7578
# Time: 134.83329892158508sec
# Epoch [127/200],i_batch=178 ,Train_Loss: 0.1616,Valid_loss: 0.7017
# Time: 137.69443941116333sec
# Epoch [128/200],i_batch=178 ,Train_Loss: 0.1357,Valid_loss: 0.7731
# Time: 136.90680766105652sec
# Epoch [129/200],i_batch=178 ,Train_Loss: 0.0527,Valid_loss: 0.7356
# Time: 135.71659016609192sec
# Epoch [130/200],i_batch=178 ,Train_Loss: 0.0522,Valid_loss: 0.7450
# Time: 133.44829678535461sec
# Epoch [131/200],i_batch=178 ,Train_Loss: 0.0529,Valid_loss: 0.7039
# Time: 134.54214882850647sec
# Epoch [132/200],i_batch=178 ,Train_Loss: 0.0494,Valid_loss: 0.7528
# Time: 129.66812467575073sec
# Epoch [133/200],i_batch=178 ,Train_Loss: 0.1008,Valid_loss: 0.7021
# Time: 133.4618537425995sec
# Epoch [134/200],i_batch=178 ,Train_Loss: 0.0490,Valid_loss: 0.8101
# Time: 133.16444396972656sec
# Epoch [135/200],i_batch=178 ,Train_Loss: 0.1477,Valid_loss: 0.7249
# Time: 104.60826134681702sec
# Epoch [136/200],i_batch=178 ,Train_Loss: 0.0917,Valid_loss: 0.7624
# Time: 100.2074089050293sec
# Epoch [137/200],i_batch=178 ,Train_Loss: 0.0420,Valid_loss: 0.7109
# Time: 103.41828560829163sec
# Epoch [138/200],i_batch=178 ,Train_Loss: 0.0583,Valid_loss: 0.7480
# Time: 103.50237393379211sec
# Epoch [139/200],i_batch=178 ,Train_Loss: 0.0944,Valid_loss: 0.7519
# Time: 99.45550775527954sec
# Epoch [140/200],i_batch=178 ,Train_Loss: 0.0503,Valid_loss: 0.7694
# Time: 104.972585439682sec
# Epoch [141/200],i_batch=178 ,Train_Loss: 0.0421,Valid_loss: 0.7460
# Time: 101.6377694606781sec
# Epoch [142/200],i_batch=178 ,Train_Loss: 0.0405,Valid_loss: 0.7324
# Time: 104.61929607391357sec
# Epoch [143/200],i_batch=178 ,Train_Loss: 0.0511,Valid_loss: 0.7223
# Time: 100.94877219200134sec
# Epoch [144/200],i_batch=178 ,Train_Loss: 0.0393,Valid_loss: 0.7638
# Time: 108.03910541534424sec
# Epoch [145/200],i_batch=178 ,Train_Loss: 0.0436,Valid_loss: 0.7816
# Time: 101.96073317527771sec
# Epoch [146/200],i_batch=178 ,Train_Loss: 0.0434,Valid_loss: 0.7587
# Time: 101.07213139533997sec
# Epoch [147/200],i_batch=178 ,Train_Loss: 0.0471,Valid_loss: 0.7326
# Time: 108.07618284225464sec
# Epoch [148/200],i_batch=178 ,Train_Loss: 0.0412,Valid_loss: 0.7852
# Time: 105.46388173103333sec
# Epoch [149/200],i_batch=178 ,Train_Loss: 0.1727,Valid_loss: 0.7885
# Time: 105.28581166267395sec
# Epoch [150/200],i_batch=178 ,Train_Loss: 0.0885,Valid_loss: 0.7793
# Time: 102.02857756614685sec
# Epoch [151/200],i_batch=178 ,Train_Loss: 0.0374,Valid_loss: 0.7644
# Time: 106.98139071464539sec
# Epoch [152/200],i_batch=178 ,Train_Loss: 0.1280,Valid_loss: 0.7582
# Time: 105.45286154747009sec
# Epoch [153/200],i_batch=178 ,Train_Loss: 0.0315,Valid_loss: 0.7553
# Time: 103.92864465713501sec
# Epoch [154/200],i_batch=178 ,Train_Loss: 0.0788,Valid_loss: 0.7849
# Time: 104.38953113555908sec
# Epoch [155/200],i_batch=178 ,Train_Loss: 0.0719,Valid_loss: 0.7701
# Time: 101.42068934440613sec
# Epoch [156/200],i_batch=178 ,Train_Loss: 0.0444,Valid_loss: 0.7612
# Time: 103.92665791511536sec
# Epoch [157/200],i_batch=178 ,Train_Loss: 0.0330,Valid_loss: 0.7759
# Time: 105.3782422542572sec
# Epoch [158/200],i_batch=178 ,Train_Loss: 0.0373,Valid_loss: 0.7405
# Time: 104.85858917236328sec
# Epoch [159/200],i_batch=178 ,Train_Loss: 0.0382,Valid_loss: 0.7537
# Time: 105.9849591255188sec
# Epoch [160/200],i_batch=178 ,Train_Loss: 0.0329,Valid_loss: 0.7540
# Time: 106.08197522163391sec
# Epoch [161/200],i_batch=178 ,Train_Loss: 0.0332,Valid_loss: 0.8105
# Time: 103.16406226158142sec
# Epoch [162/200],i_batch=178 ,Train_Loss: 0.0333,Valid_loss: 0.7756
# Time: 102.19071674346924sec
# Epoch [163/200],i_batch=178 ,Train_Loss: 0.0344,Valid_loss: 0.7336
# Time: 102.21279764175415sec
# Epoch [164/200],i_batch=178 ,Train_Loss: 0.0361,Valid_loss: 0.7804
# Time: 107.21043562889099sec
# Epoch [165/200],i_batch=178 ,Train_Loss: 0.0344,Valid_loss: 0.7627
# Time: 102.4057629108429sec
# Epoch [166/200],i_batch=178 ,Train_Loss: 0.1184,Valid_loss: 0.7512
# Time: 103.49564862251282sec
# Epoch [167/200],i_batch=178 ,Train_Loss: 0.0280,Valid_loss: 0.7588
# Time: 104.9812376499176sec
# Epoch [168/200],i_batch=178 ,Train_Loss: 0.0310,Valid_loss: 0.7715
# Time: 106.13445234298706sec
# Epoch [169/200],i_batch=178 ,Train_Loss: 0.0310,Valid_loss: 0.7763
# Time: 103.31051301956177sec
# Epoch [170/200],i_batch=178 ,Train_Loss: 0.0343,Valid_loss: 0.7878
# Time: 106.5557508468628sec
# Epoch [171/200],i_batch=178 ,Train_Loss: 0.0318,Valid_loss: 0.7924
# Time: 101.36868166923523sec
# Epoch [172/200],i_batch=178 ,Train_Loss: 0.1039,Valid_loss: 0.7705
# Time: 104.43294644355774sec
# Epoch [173/200],i_batch=178 ,Train_Loss: 0.0269,Valid_loss: 0.7754
# Time: 100.35686612129211sec
# Epoch [174/200],i_batch=178 ,Train_Loss: 0.0268,Valid_loss: 0.7881
# Time: 108.7727918624878sec
# Epoch [175/200],i_batch=178 ,Train_Loss: 0.0311,Valid_loss: 0.8113
# Time: 102.75784707069397sec
# Epoch [176/200],i_batch=178 ,Train_Loss: 0.0289,Valid_loss: 0.8160
# Time: 103.3521032333374sec
# Epoch [177/200],i_batch=178 ,Train_Loss: 0.0947,Valid_loss: 0.8429
# Time: 104.9467842578888sec
# Epoch [178/200],i_batch=178 ,Train_Loss: 0.0248,Valid_loss: 0.7985
# Time: 103.95293831825256sec
# Epoch [179/200],i_batch=178 ,Train_Loss: 0.0235,Valid_loss: 0.7894
# Time: 104.34509181976318sec
# Epoch [180/200],i_batch=178 ,Train_Loss: 0.0275,Valid_loss: 0.7650
# Time: 101.7413923740387sec
# Epoch [181/200],i_batch=178 ,Train_Loss: 0.1085,Valid_loss: 0.8481
# Time: 102.15439486503601sec
# Epoch [182/200],i_batch=178 ,Train_Loss: 0.0931,Valid_loss: 0.8698
# Time: 106.1707055568695sec
# Epoch [183/200],i_batch=178 ,Train_Loss: 0.0637,Valid_loss: 0.8448
# Time: 108.04689407348633sec
# Epoch [184/200],i_batch=178 ,Train_Loss: 0.0300,Valid_loss: 0.7882
# Time: 106.4115891456604sec
# Epoch [185/200],i_batch=178 ,Train_Loss: 0.0212,Valid_loss: 0.7941
# Time: 106.04869413375854sec
# Epoch [186/200],i_batch=178 ,Train_Loss: 0.0248,Valid_loss: 0.8222
# Time: 101.2795000076294sec
# Epoch [187/200],i_batch=178 ,Train_Loss: 0.0270,Valid_loss: 0.8005
# Time: 104.9084324836731sec
# Epoch [188/200],i_batch=178 ,Train_Loss: 0.0289,Valid_loss: 0.6959
# Time: 105.1200659275055sec
# Epoch [189/200],i_batch=178 ,Train_Loss: 0.0949,Valid_loss: 0.8128
# Time: 104.6886100769043sec
# Epoch [190/200],i_batch=178 ,Train_Loss: 0.0264,Valid_loss: 0.8102
# Time: 103.17342853546143sec
# Epoch [191/200],i_batch=178 ,Train_Loss: 0.0235,Valid_loss: 0.8114
# Time: 103.00169253349304sec
# Epoch [192/200],i_batch=178 ,Train_Loss: 0.0202,Valid_loss: 0.8088
# Time: 100.81769156455994sec
# Epoch [193/200],i_batch=178 ,Train_Loss: 0.0684,Valid_loss: 0.8044
# Time: 107.11196947097778sec
# Epoch [194/200],i_batch=178 ,Train_Loss: 0.0830,Valid_loss: 0.8131
# Time: 102.69690823554993sec
# Epoch [195/200],i_batch=178 ,Train_Loss: 0.0267,Valid_loss: 0.7836
# Time: 106.84304070472717sec
# Epoch [196/200],i_batch=178 ,Train_Loss: 0.0218,Valid_loss: 0.8562
# Time: 102.88126993179321sec
# Epoch [197/200],i_batch=178 ,Train_Loss: 0.0218,Valid_loss: 0.8014
# Time: 106.7176079750061sec
# Epoch [198/200],i_batch=178 ,Train_Loss: 0.0487,Valid_loss: 0.8107
# Time: 106.76279497146606sec
# Epoch [199/200],i_batch=178 ,Train_Loss: 0.0208,Valid_loss: 0.8661
# Time: 104.80152583122253sec
# Epoch [200/200],i_batch=178 ,Train_Loss: 0.0211,Valid_loss: 0.8399
# Time: 106.09566736221313sec

# %%
plt.plot(train_loss_history)
plt.plot(valid_loss_history)
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
import csv


with open("v_loss_min_2phase.csv", 'w') as file:
  writer = csv.writer(file)
  writer.writerow(valid_loss_history)
with open("t_loss_min_2phase.csv", 'w') as file:
  writer = csv.writer(file)
  writer.writerow(train_loss_history)

# %%
true_label=[]
pred_label=[]

model=CustomConvNet().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=hyper_param_learning_rate)

checkpoint = torch.load('/home/sumins/workspace/washout classification/model_save/model5.pth')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
loss = checkpoint['loss']
print(loss)
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for item in test_loader:
        npys = item['npy'].to(device)
        labels = item['label'].to(device)
        
        outputs =model(npys)
        _, predicted = torch.max(outputs.data, 1)
        true_label.extend(labels)
        pred_label.extend(predicted)
        total += len(labels)
       
        correct += (predicted == labels).sum().item()
        
    print('Test Accuracy of the model on the {} test images: {} %'.format(total, 100 * correct / total))
# Out:
# tensor(0.1957, device='cuda:0', requires_grad=True)
# Test Accuracy of the model on the 363 test images: 69.97245179063361 %

# %%
true_labels=torch.tensor(true_label)
true_labels=true_labels.tolist()
pred_labels=torch.tensor(pred_label)
pred_labels=pred_labels.tolist()
print(classification_report(true_labels,pred_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.12      0.01      0.02       103
#            1       0.71      0.97      0.82       260
#
#     accuracy                           0.70       363
#    macro avg       0.42      0.49      0.42       363
# weighted avg       0.55      0.70      0.59       363

# %%
true_label=[]
pred_label=[]

model=CustomConvNet().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=hyper_param_learning_rate)

checkpoint = torch.load('/home/sumins/workspace/washout classification/model_save/model5.pth')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
loss = checkpoint['loss']
print(loss)
print(epoch)
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for item in train_loader:
        npys = item['npy'].to(device)
        labels = item['label'].to(device)
        
        outputs =model(npys)
        _, predicted = torch.max(outputs.data, 1)
        true_label.extend(labels)
        pred_label.extend(predicted)
        total += len(labels)
       
        correct += (predicted == labels).sum().item()
        
    print('Test Accuracy of the model on the {} test images: {} %'.format(total, 100 * correct / total))
# Out:
# tensor(0.1957, device='cuda:0', requires_grad=True)
# 53
# Test Accuracy of the model on the 1422 test images: 100.0 %

# %%
true_labels=torch.tensor(true_label)
true_labels=true_labels.tolist()
pred_labels=torch.tensor(pred_label)
pred_labels=pred_labels.tolist()
print(classification_report(true_labels,pred_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       343
#            1       1.00      1.00      1.00      1079
#
#     accuracy                           1.00      1422
#    macro avg       1.00      1.00      1.00      1422
# weighted avg       1.00      1.00      1.00      1422
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다. 셀의 코드를 검토하여 오류의 가능한 원인을 식별하세요. 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'> 여기 </a> 를 클릭하세요. 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
