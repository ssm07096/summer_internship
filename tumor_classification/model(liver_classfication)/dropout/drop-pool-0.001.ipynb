# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  
os.environ["CUDA_VISIBLE_DEVICES"]="7"

# %%
import numpy as np
from matplotlib import pyplot as plt
import nibabel as nib
from PIL import Image
from matplotlib import pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
from sklearn.model_selection import train_test_split
import torchsummary
from torchvision import transforms
import time
from sklearn.metrics import classification_report

# %%
#파일이름 sort해서 list저장
data_path='/disk1/data_liverbound_noclip/'
name_list=os.listdir(data_path)

segmentation_data = [files[:-4] for files in name_list if files.startswith('segmentation')]
segmentation_data=list(set(segmentation_data))
segmentation_data.sort()
seg_data_test=[]
for i in range(30,45):
    seg_data_test.append(segmentation_data.pop(i))

volume_data=[files[:-4] for files in name_list if files.startswith('volume')]
volume_data=list(set(volume_data))
volume_data.sort()
vol_data_test=[]
for i in range(30,45):
    vol_data_test.append(volume_data.pop(i))

# %%
# all_labels=np.loadtxt('/home/sumins/workspace/liver_classification/all_labels.txt',dtype=int)
# all_labels=all_labels.tolist()

# %%
#npy를 slice별로 나누어 하나의 list저장
seg_list_train=[]
seg_list_test=[]
for file in segmentation_data:
    fname=os.path.basename(file)
    print(fname)
    img_array=np.load(data_path+fname+'.npy')
    
    #print(f'img_num: {img_array.shape}')
    
    if len(img_array.shape) == 3:
        nx, ny, nz = img_array.shape
        total_slices = img_array.shape[2]
        #print(total_slices)
        # iterate through slices
        for current_slice in range(0, total_slices):
            seg_list_train.append(img_array[:,:,current_slice]) 

for file in seg_data_test:
    fname=os.path.basename(file)
    print(fname)
    img_array=np.load(data_path+fname+'.npy')
    
    #print(f'img_num: {img_array.shape}')
    
    if len(img_array.shape) == 3:
        nx, ny, nz = img_array.shape
        total_slices = img_array.shape[2]
        print(total_slices)
        # iterate through slices
        for current_slice in range(0, total_slices):
            seg_list_test.append(img_array[:,:,current_slice]) 
#간 1, 병변 2, 나머지 0


vol_list_train=[]
vol_list_test=[]
for file in volume_data:
    fname=os.path.basename(file)
    print(fname)
    img_array=np.load(data_path+fname+'.npy')
    
    #print(f'img_num: {img_array.shape}')
    
    if len(img_array.shape) == 3:
        nx, ny, nz = img_array.shape
        total_slices = img_array.shape[2]
        # iterate through slices
        for current_slice in range(0, total_slices):
            vol_list_train.append(img_array[:,:,current_slice]) 
            
for file in vol_data_test:
    fname=os.path.basename(file)
    print(fname)
    img_array=np.load(data_path+fname+'.npy')
    
    #print(f'img_num: {img_array.shape}')
    
    if len(img_array.shape) == 3:
        nx, ny, nz = img_array.shape
        total_slices = img_array.shape[2]
        # iterate through slices
        for current_slice in range(0, total_slices):
            vol_list_test.append(img_array[:,:,current_slice])
# Out:
# segmentation-0
# segmentation-1
# segmentation-10
# segmentation-100
# segmentation-101
# segmentation-102
# segmentation-103
# segmentation-104
# segmentation-105
# segmentation-106
# segmentation-107
# segmentation-108
# segmentation-109
# segmentation-11
# segmentation-110
# segmentation-111
# segmentation-112
# segmentation-113
# segmentation-114
# segmentation-115
# segmentation-116
# segmentation-117
# segmentation-118
# segmentation-119
# segmentation-12
# segmentation-120
# segmentation-121
# segmentation-122
# segmentation-123
# segmentation-124
# segmentation-126
# segmentation-128
# segmentation-13
# segmentation-15
# segmentation-17
# segmentation-19
# segmentation-20
# segmentation-22
# segmentation-24
# segmentation-26
# segmentation-28
# segmentation-3
# segmentation-31
# segmentation-33
# segmentation-35
# segmentation-36
# segmentation-37
# segmentation-38
# segmentation-39
# segmentation-4
# segmentation-40
# segmentation-41
# segmentation-42
# segmentation-43
# segmentation-44
# segmentation-45
# segmentation-46
# segmentation-47
# segmentation-48
# segmentation-49
# segmentation-5
# segmentation-50
# segmentation-51
# segmentation-52
# segmentation-53
# segmentation-54
# segmentation-55
# segmentation-56
# segmentation-57
# segmentation-58
# segmentation-59
# segmentation-6
# segmentation-60
# segmentation-61
# segmentation-62
# segmentation-63
# segmentation-64
# segmentation-65
# segmentation-66
# segmentation-67
# segmentation-68
# segmentation-69
# segmentation-7
# segmentation-70
# segmentation-71
# segmentation-72
# segmentation-73
# segmentation-74
# segmentation-75
# segmentation-76
# segmentation-77
# segmentation-78
# segmentation-79
# segmentation-8
# segmentation-80
# segmentation-81
# segmentation-82
# segmentation-83
# segmentation-84
# segmentation-85
# segmentation-86
# segmentation-87
# segmentation-88
# segmentation-89
# segmentation-9
# segmentation-90
# segmentation-91
# segmentation-92
# segmentation-93
# segmentation-94
# segmentation-95
# segmentation-96
# segmentation-97
# segmentation-98
# segmentation-99
# segmentation-125
# 133
# segmentation-127
# 270
# segmentation-129
# 325
# segmentation-14
# 164
# segmentation-16
# 222
# segmentation-18
# 224
# segmentation-2
# 164
# segmentation-21
# 191
# segmentation-23
# 137
# segmentation-25
# 277
# segmentation-27
# 272
# segmentation-29
# 135
# segmentation-30
# 146
# segmentation-32
# 128
# segmentation-34
# 109
# volume-0
# volume-1
# volume-10
# volume-100
# volume-101
# volume-102
# volume-103
# volume-104
# volume-105
# volume-106
# volume-107
# volume-108
# volume-109
# volume-11
# volume-110
# volume-111
# volume-112
# volume-113
# volume-114
# volume-115
# volume-116
# volume-117
# volume-118
# volume-119
# volume-12
# volume-120
# volume-121
# volume-122
# volume-123
# volume-124
# volume-126
# volume-128
# volume-13
# volume-15
# volume-17
# volume-19
# volume-20
# volume-22
# volume-24
# volume-26
# volume-28
# volume-3
# volume-31
# volume-33
# volume-35
# volume-36
# volume-37
# volume-38
# volume-39
# volume-4
# volume-40
# volume-41
# volume-42
# volume-43
# volume-44
# volume-45
# volume-46
# volume-47
# volume-48
# volume-49
# volume-5
# volume-50
# volume-51
# volume-52
# volume-53
# volume-54
# volume-55
# volume-56
# volume-57
# volume-58
# volume-59
# volume-6
# volume-60
# volume-61
# volume-62
# volume-63
# volume-64
# volume-65
# volume-66
# volume-67
# volume-68
# volume-69
# volume-7
# volume-70
# volume-71
# volume-72
# volume-73
# volume-74
# volume-75
# volume-76
# volume-77
# volume-78
# volume-79
# volume-8
# volume-80
# volume-81
# volume-82
# volume-83
# volume-84
# volume-85
# volume-86
# volume-87
# volume-88
# volume-89
# volume-9
# volume-90
# volume-91
# volume-92
# volume-93
# volume-94
# volume-95
# volume-96
# volume-97
# volume-98
# volume-99
# volume-125
# volume-127
# volume-129
# volume-14
# volume-16
# volume-18
# volume-2
# volume-21
# volume-23
# volume-25
# volume-27
# volume-29
# volume-30
# volume-32
# volume-34

# %%
#label을 만들어 list에 저장
labels_train = []
labels_test=[]
for i in seg_list_test:
    if 2 in i:
        labels_test.append(1)
    else:
        labels_test.append(0)
        
for i in seg_list_train:
    if 2 in i:
        labels_train.append(1)
    else:
        labels_train.append(0)

# %%
def norm(nparray):
    # normalize scans to [0,1]
    _min = nparray.min()
    _max = nparray.max()
    nparray = nparray - _min
    nparray = nparray / (_max - _min)
    return nparray

def norm_zscore(nparray):
    # normalize 2d scands by mean and standard deviation
    mean = nparray.mean()
    std = nparray.std()    
    nparray = nparray - mean
    nparray /= std
    return nparray

# %%
WINDOW_MAX = 200
WINDOW_MIN = 0
GLOBAL_PIXEL_MEAN = 0.1

class CustomDataset(Dataset): 
  def __init__(self,volume_list,all_labels,transforms=None):
    self.volume_list=volume_list
    self.all_labels=all_labels
    self.length=len(all_labels)
    self.transforms=transforms


  def __len__(self):
    return self.length


  def __getitem__(self, idx):
    npy=self.volume_list[idx]

    npy[npy > WINDOW_MAX] = WINDOW_MAX
    npy[npy < WINDOW_MIN] = WINDOW_MIN
    
    npy = (npy - WINDOW_MIN) / (WINDOW_MAX - WINDOW_MIN)
    npy -= GLOBAL_PIXEL_MEAN
    
    if len(npy.shape)==2:
      npy=npy[:,:,np.newaxis].astype(dtype='float32')
    
    if self.transforms is not None:
      npy=self.transforms(npy)
    
    return{'npy':npy,'label':self.all_labels[idx]}

# %%
class CustomConvNet(nn.Module):
    def __init__(self):
        super(CustomConvNet, self).__init__() #상속받은 class에 접근하기 위함

        self.layer1 = self.conv_module(1, 16) #흑백사진은 inp
        self.layer2 = self.conv_module(16, 32)
        self.layer3 = self.conv_module(32, 64)
        self.layer4 = self.conv_module(64, 128)
        self.layer5 = self.conv_module(128, 256)
        self.gap = self.global_avg_pool(256, 2)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        out = self.gap(out)
        out = out.view(-1, 2)

        return out

    def conv_module(self, in_num, out_num):
        return nn.Sequential(
            nn.Conv2d(in_num, out_num, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(out_num),
            nn.LeakyReLU(),
            nn.Dropout(0.4),
            nn.MaxPool2d(kernel_size=2, stride=2))

    def global_avg_pool(self, in_num, out_num):
        return nn.Sequential(
            nn.Conv2d(in_num, out_num, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(out_num),
            nn.LeakyReLU(),
            nn.AdaptiveAvgPool2d((1,1)))
        
model=CustomConvNet()
torchsummary.summary(model.cuda(),input_size=(1,512,512),batch_size=1)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [1, 16, 512, 512]             160
#        BatchNorm2d-2          [1, 16, 512, 512]              32
#          LeakyReLU-3          [1, 16, 512, 512]               0
#            Dropout-4          [1, 16, 512, 512]               0
#          MaxPool2d-5          [1, 16, 256, 256]               0
#             Conv2d-6          [1, 32, 256, 256]           4,640
#        BatchNorm2d-7          [1, 32, 256, 256]              64
#          LeakyReLU-8          [1, 32, 256, 256]               0
#            Dropout-9          [1, 32, 256, 256]               0
#         MaxPool2d-10          [1, 32, 128, 128]               0
#            Conv2d-11          [1, 64, 128, 128]          18,496
#       BatchNorm2d-12          [1, 64, 128, 128]             128
#         LeakyReLU-13          [1, 64, 128, 128]               0
#           Dropout-14          [1, 64, 128, 128]               0
#         MaxPool2d-15            [1, 64, 64, 64]               0
#            Conv2d-16           [1, 128, 64, 64]          73,856
#       BatchNorm2d-17           [1, 128, 64, 64]             256
#         LeakyReLU-18           [1, 128, 64, 64]               0
#           Dropout-19           [1, 128, 64, 64]               0
#         MaxPool2d-20           [1, 128, 32, 32]               0
#            Conv2d-21           [1, 256, 32, 32]         295,168
#       BatchNorm2d-22           [1, 256, 32, 32]             512
#         LeakyReLU-23           [1, 256, 32, 32]               0
#           Dropout-24           [1, 256, 32, 32]               0
#         MaxPool2d-25           [1, 256, 16, 16]               0
#            Conv2d-26             [1, 2, 16, 16]           4,610
#       BatchNorm2d-27             [1, 2, 16, 16]               4
#         LeakyReLU-28             [1, 2, 16, 16]               0
# AdaptiveAvgPool2d-29               [1, 2, 1, 1]               0
# ================================================================
# Total params: 397,926
# Trainable params: 397,926
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 1.00
# Forward/backward pass size (MB): 263.51
# Params size (MB): 1.52
# Estimated Total Size (MB): 266.03
# ----------------------------------------------------------------

# %%
transforms_train = transforms.Compose([transforms.ToTensor()
                                       ])
transforms_test = transforms.Compose([transforms.ToTensor()
                                       ])

hyper_param_epoch=100
hyper_param_batch=32
hyper_param_learning_rate=0.001

# %%
#vol_train, vol_valid, lab_train, lab_valid = train_test_split(volume_list, all_labels, test_size=0.3, shuffle=True, stratify=all_labels, random_state=34)
train_dataset=CustomDataset(volume_list=vol_list_train, all_labels=labels_train,transforms=transforms_train)
test_dataset=CustomDataset(volume_list=vol_list_test,all_labels=labels_test,transforms=transforms_test)
train_loader = DataLoader(train_dataset, batch_size=hyper_param_batch, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=hyper_param_batch, shuffle=True)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device,"/" ,torch.cuda.device_count())

custom_model=CustomConvNet().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(custom_model.parameters(), lr=hyper_param_learning_rate)
# Out:
# cuda:0 / 1

# %%
def validation_loss(model):
    total_loss=0
    for i_batch, item in enumerate(test_loader):
        npys = item['npy'].to(device)
        labels = item['label'].to(device)
 
        outputs =model(npys)
        loss = criterion(outputs, labels)

        total_loss+=loss.item()
    return total_loss/(i_batch+1)

# %%
loss_value=1
start=time.time()
custom_model.train()
train_loss_history=[]
valid_loss_history=[]
val_loss=0
for e in range(hyper_param_epoch):
        for i_batch, item in enumerate(train_loader):
                npys = item['npy'].to(device)
                labels = item['label'].to(device)
                #print(npys)
                # Forward pass
                outputs =custom_model(npys)
                loss = criterion(outputs, labels)

                # Backward and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
        val_loss=validation_loss(custom_model)
        train_loss_history.append(loss.item())
        valid_loss_history.append(val_loss)
        print('Epoch [{}/{}],i_batch={} ,Train_Loss: {:.4f},Valid_loss: {:.4f}'
                                        .format(e + 1, hyper_param_epoch, i_batch+1, loss.item(),val_loss))
        print("Time: {}sec".format(time.time()-start))
        start=time.time()
        if loss_value>val_loss:
                loss_value=val_loss
                torch.save({
                'epoch': e,
                'model_state_dict': custom_model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': loss,
                }, '/home/sumins/workspace/model_check/model_dropout_position.pth')
# Out:
# Epoch [1/100],i_batch=604 ,Train_Loss: 0.6027,Valid_loss: 0.5589
# Time: 85.15137887001038sec
# Epoch [2/100],i_batch=604 ,Train_Loss: 0.5095,Valid_loss: 0.5318
# Time: 95.1379759311676sec
# Epoch [3/100],i_batch=604 ,Train_Loss: 0.4655,Valid_loss: 0.5553
# Time: 84.78492045402527sec
# Epoch [4/100],i_batch=604 ,Train_Loss: 0.5736,Valid_loss: 0.5248
# Time: 84.71707272529602sec
# Epoch [5/100],i_batch=604 ,Train_Loss: 0.3126,Valid_loss: 0.5193
# Time: 84.98438477516174sec
# Epoch [6/100],i_batch=604 ,Train_Loss: 0.3002,Valid_loss: 0.5150
# Time: 106.03746891021729sec
# Epoch [7/100],i_batch=604 ,Train_Loss: 0.5881,Valid_loss: 0.5192
# Time: 102.33255410194397sec
# Epoch [8/100],i_batch=604 ,Train_Loss: 0.4797,Valid_loss: 0.5278
# Time: 179.4171850681305sec
# Epoch [9/100],i_batch=604 ,Train_Loss: 0.3831,Valid_loss: 0.4873
# Time: 199.2215075492859sec
# Epoch [10/100],i_batch=604 ,Train_Loss: 0.1886,Valid_loss: 0.4590
# Time: 125.68510365486145sec
# Epoch [11/100],i_batch=604 ,Train_Loss: 0.1944,Valid_loss: 0.5014
# Time: 128.3043987751007sec
# Epoch [12/100],i_batch=604 ,Train_Loss: 0.3275,Valid_loss: 0.4676
# Time: 125.35552263259888sec
# Epoch [13/100],i_batch=604 ,Train_Loss: 0.2293,Valid_loss: 0.5063
# Time: 192.38638544082642sec
# Epoch [14/100],i_batch=604 ,Train_Loss: 0.1480,Valid_loss: 0.5287
# Time: 199.56986093521118sec
# Epoch [15/100],i_batch=604 ,Train_Loss: 0.2185,Valid_loss: 0.5596
# Time: 175.86842131614685sec
# Epoch [16/100],i_batch=604 ,Train_Loss: 0.1110,Valid_loss: 0.4803
# Time: 224.63953137397766sec
# Epoch [17/100],i_batch=604 ,Train_Loss: 0.0747,Valid_loss: 0.4801
# Time: 181.4828712940216sec
# Epoch [18/100],i_batch=604 ,Train_Loss: 0.2719,Valid_loss: 0.5060
# Time: 179.06287813186646sec
# Epoch [19/100],i_batch=604 ,Train_Loss: 0.1006,Valid_loss: 0.4922
# Time: 182.14005327224731sec
# Epoch [20/100],i_batch=604 ,Train_Loss: 0.2202,Valid_loss: 0.5404
# Time: 172.0174205303192sec
# Epoch [21/100],i_batch=604 ,Train_Loss: 0.1036,Valid_loss: 0.4930
# Time: 171.86033511161804sec
# Epoch [22/100],i_batch=604 ,Train_Loss: 0.0999,Valid_loss: 0.6158
# Time: 169.24940371513367sec
# Epoch [23/100],i_batch=604 ,Train_Loss: 0.0536,Valid_loss: 0.5175
# Time: 168.65912985801697sec
# Epoch [24/100],i_batch=604 ,Train_Loss: 0.2885,Valid_loss: 0.5565
# Time: 113.33430671691895sec
# Epoch [25/100],i_batch=604 ,Train_Loss: 0.0725,Valid_loss: 0.7290
# Time: 115.63861107826233sec
# Epoch [26/100],i_batch=604 ,Train_Loss: 0.1005,Valid_loss: 0.5385
# Time: 114.22573590278625sec
# Epoch [27/100],i_batch=604 ,Train_Loss: 0.1327,Valid_loss: 0.5819
# Time: 128.21900153160095sec
# Epoch [28/100],i_batch=604 ,Train_Loss: 0.0644,Valid_loss: 0.6215
# Time: 114.41541123390198sec
# Epoch [29/100],i_batch=604 ,Train_Loss: 0.1087,Valid_loss: 0.5632
# Time: 116.62566256523132sec
# Epoch [30/100],i_batch=604 ,Train_Loss: 0.1415,Valid_loss: 0.5429
# Time: 113.98767971992493sec
# Epoch [31/100],i_batch=604 ,Train_Loss: 0.0377,Valid_loss: 0.5765
# Time: 114.81066083908081sec
# Epoch [32/100],i_batch=604 ,Train_Loss: 0.1717,Valid_loss: 0.5998
# Time: 112.61652874946594sec
# Epoch [33/100],i_batch=604 ,Train_Loss: 0.0358,Valid_loss: 0.5660
# Time: 114.9929883480072sec
# Epoch [34/100],i_batch=604 ,Train_Loss: 0.2104,Valid_loss: 0.7049
# Time: 114.14476156234741sec
# Epoch [35/100],i_batch=604 ,Train_Loss: 0.0915,Valid_loss: 0.6210
# Time: 116.79198169708252sec
# Epoch [36/100],i_batch=604 ,Train_Loss: 0.0151,Valid_loss: 0.7866
# Time: 112.42601299285889sec
# Epoch [37/100],i_batch=604 ,Train_Loss: 0.0534,Valid_loss: 0.5647
# Time: 114.647047996521sec
# Epoch [38/100],i_batch=604 ,Train_Loss: 0.0586,Valid_loss: 0.6739
# Time: 115.46405339241028sec
# Epoch [39/100],i_batch=604 ,Train_Loss: 0.0235,Valid_loss: 0.5381
# Time: 116.22955536842346sec
# Epoch [40/100],i_batch=604 ,Train_Loss: 0.0438,Valid_loss: 0.7850
# Time: 116.84908866882324sec
# Epoch [41/100],i_batch=604 ,Train_Loss: 0.1118,Valid_loss: 0.6512
# Time: 116.14876294136047sec
# Epoch [42/100],i_batch=604 ,Train_Loss: 0.0710,Valid_loss: 0.6610
# Time: 113.76507830619812sec
# Epoch [43/100],i_batch=604 ,Train_Loss: 0.0232,Valid_loss: 0.6367
# Time: 115.75674438476562sec
# Epoch [44/100],i_batch=604 ,Train_Loss: 0.0280,Valid_loss: 0.7222
# Time: 116.48077964782715sec
# Epoch [45/100],i_batch=604 ,Train_Loss: 0.0278,Valid_loss: 0.7104
# Time: 115.69340515136719sec
# Epoch [46/100],i_batch=604 ,Train_Loss: 0.0502,Valid_loss: 0.5728
# Time: 114.84348964691162sec
# Epoch [47/100],i_batch=604 ,Train_Loss: 0.1561,Valid_loss: 0.6668
# Time: 116.07440042495728sec
# Epoch [48/100],i_batch=604 ,Train_Loss: 0.0198,Valid_loss: 0.5974
# Time: 114.94514513015747sec
# Epoch [49/100],i_batch=604 ,Train_Loss: 0.1152,Valid_loss: 0.6446
# Time: 111.66588020324707sec
# Epoch [50/100],i_batch=604 ,Train_Loss: 0.0053,Valid_loss: 0.6053
# Time: 118.14348363876343sec
# Epoch [51/100],i_batch=604 ,Train_Loss: 0.0087,Valid_loss: 0.5680
# Time: 117.5651445388794sec
# Epoch [52/100],i_batch=604 ,Train_Loss: 0.0308,Valid_loss: 0.6312
# Time: 118.06280660629272sec
# Epoch [53/100],i_batch=604 ,Train_Loss: 0.1734,Valid_loss: 0.6442
# Time: 129.62969207763672sec
# Epoch [54/100],i_batch=604 ,Train_Loss: 0.0086,Valid_loss: 0.6493
# Time: 116.31072664260864sec
# Epoch [55/100],i_batch=604 ,Train_Loss: 0.0356,Valid_loss: 0.7128
# Time: 116.06855034828186sec
# Epoch [56/100],i_batch=604 ,Train_Loss: 0.1462,Valid_loss: 0.7033
# Time: 114.60086131095886sec
# Epoch [57/100],i_batch=604 ,Train_Loss: 0.2723,Valid_loss: 0.6711
# Time: 116.52763223648071sec
# Epoch [58/100],i_batch=604 ,Train_Loss: 0.0124,Valid_loss: 0.7114
# Time: 114.39428067207336sec
# Epoch [59/100],i_batch=604 ,Train_Loss: 0.0152,Valid_loss: 0.6269
# Time: 115.93259143829346sec
# Epoch [60/100],i_batch=604 ,Train_Loss: 0.1091,Valid_loss: 0.7134
# Time: 116.47575759887695sec
# Epoch [61/100],i_batch=604 ,Train_Loss: 0.0051,Valid_loss: 0.6273
# Time: 116.00504946708679sec
# Epoch [62/100],i_batch=604 ,Train_Loss: 0.0348,Valid_loss: 0.6724
# Time: 115.39107990264893sec
# Epoch [63/100],i_batch=604 ,Train_Loss: 0.0106,Valid_loss: 0.6637
# Time: 116.78139567375183sec
# Epoch [64/100],i_batch=604 ,Train_Loss: 0.1879,Valid_loss: 0.6630
# Time: 115.59254908561707sec
# Epoch [65/100],i_batch=604 ,Train_Loss: 0.0077,Valid_loss: 0.6519
# Time: 114.95177054405212sec
# Epoch [66/100],i_batch=604 ,Train_Loss: 0.0389,Valid_loss: 0.6713
# Time: 127.48433256149292sec
# Epoch [67/100],i_batch=604 ,Train_Loss: 0.0594,Valid_loss: 0.6746
# Time: 139.5789818763733sec
# Epoch [68/100],i_batch=604 ,Train_Loss: 0.0496,Valid_loss: 0.8436
# Time: 113.61723399162292sec
# Epoch [69/100],i_batch=604 ,Train_Loss: 0.1489,Valid_loss: 0.6598
# Time: 113.01878237724304sec
# Epoch [70/100],i_batch=604 ,Train_Loss: 0.1067,Valid_loss: 0.7396
# Time: 112.59287095069885sec
# Epoch [71/100],i_batch=604 ,Train_Loss: 0.0247,Valid_loss: 0.6589
# Time: 111.96063208580017sec
# Epoch [72/100],i_batch=604 ,Train_Loss: 0.1028,Valid_loss: 0.8745
# Time: 113.01102828979492sec
# Epoch [73/100],i_batch=604 ,Train_Loss: 0.0141,Valid_loss: 0.6112
# Time: 83.9075038433075sec
# Epoch [74/100],i_batch=604 ,Train_Loss: 0.0326,Valid_loss: 0.6495
# Time: 83.93691968917847sec
# Epoch [75/100],i_batch=604 ,Train_Loss: 0.1089,Valid_loss: 0.6579
# Time: 84.18240642547607sec
# Epoch [76/100],i_batch=604 ,Train_Loss: 0.0455,Valid_loss: 0.6366
# Time: 84.09208178520203sec
# Epoch [77/100],i_batch=604 ,Train_Loss: 0.0276,Valid_loss: 0.6975
# Time: 84.12677097320557sec
# Epoch [78/100],i_batch=604 ,Train_Loss: 0.0183,Valid_loss: 0.6667
# Time: 84.29430508613586sec
# Epoch [79/100],i_batch=604 ,Train_Loss: 0.0034,Valid_loss: 0.7978
# Time: 84.21096324920654sec
# Epoch [80/100],i_batch=604 ,Train_Loss: 0.0333,Valid_loss: 0.7193
# Time: 84.07904148101807sec
# Epoch [81/100],i_batch=604 ,Train_Loss: 0.0127,Valid_loss: 0.7404
# Time: 85.60075783729553sec
# Epoch [82/100],i_batch=604 ,Train_Loss: 0.2988,Valid_loss: 0.7049
# Time: 84.74332094192505sec
# Epoch [83/100],i_batch=604 ,Train_Loss: 0.0096,Valid_loss: 0.7323
# Time: 84.48637819290161sec
# Epoch [84/100],i_batch=604 ,Train_Loss: 0.0049,Valid_loss: 0.7618
# Time: 84.21664524078369sec
# Epoch [85/100],i_batch=604 ,Train_Loss: 0.0150,Valid_loss: 0.7569
# Time: 84.65202832221985sec
# Epoch [86/100],i_batch=604 ,Train_Loss: 0.0097,Valid_loss: 0.7379
# Time: 84.48545551300049sec
# Epoch [87/100],i_batch=604 ,Train_Loss: 0.0845,Valid_loss: 0.6809
# Time: 84.39652729034424sec
# Epoch [88/100],i_batch=604 ,Train_Loss: 0.0031,Valid_loss: 0.7133
# Time: 84.39475846290588sec
# Epoch [89/100],i_batch=604 ,Train_Loss: 0.5238,Valid_loss: 0.7099
# Time: 84.4271502494812sec
# Epoch [90/100],i_batch=604 ,Train_Loss: 0.0214,Valid_loss: 0.7335
# Time: 84.59490585327148sec
# Epoch [91/100],i_batch=604 ,Train_Loss: 0.0187,Valid_loss: 0.7480
# Time: 84.64617133140564sec
# Epoch [92/100],i_batch=604 ,Train_Loss: 0.0370,Valid_loss: 0.7786
# Time: 84.26855945587158sec
# Epoch [93/100],i_batch=604 ,Train_Loss: 0.0326,Valid_loss: 0.7430
# Time: 84.5349588394165sec
# Epoch [94/100],i_batch=604 ,Train_Loss: 0.0014,Valid_loss: 0.8171
# Time: 84.22874474525452sec
# Epoch [95/100],i_batch=604 ,Train_Loss: 0.1063,Valid_loss: 0.7379
# Time: 84.35437107086182sec
# Epoch [96/100],i_batch=604 ,Train_Loss: 0.0034,Valid_loss: 0.7198
# Time: 85.06670713424683sec
# Epoch [97/100],i_batch=604 ,Train_Loss: 0.0051,Valid_loss: 0.6970
# Time: 84.43301677703857sec
# Epoch [98/100],i_batch=604 ,Train_Loss: 0.0064,Valid_loss: 0.6358
# Time: 84.54136323928833sec
# Epoch [99/100],i_batch=604 ,Train_Loss: 0.0019,Valid_loss: 0.7731
# Time: 85.14574909210205sec
# Epoch [100/100],i_batch=604 ,Train_Loss: 0.0066,Valid_loss: 0.6716
# Time: 84.50198149681091sec

# %%
plt.plot(train_loss_history)
plt.plot(valid_loss_history)
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
import csv


with open("valid_position.csv", 'w') as file:
  writer = csv.writer(file)
  writer.writerow(valid_loss_history)

# %%
import csv


with open("train_position.csv", 'w') as file:
  writer = csv.writer(file)
  writer.writerow(train_loss_history)

# %%
true_label=[]
pred_label=[]

model=CustomConvNet().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=hyper_param_learning_rate)

checkpoint = torch.load('/home/sumins/workspace/model_check/model_dropout_position.pth')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
loss = checkpoint['loss']
print(epoch)
print(loss)
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for item in test_loader:
        npys = item['npy'].to(device)
        labels = item['label'].to(device)
        
        outputs =model(npys)
        _, predicted = torch.max(outputs.data, 1)
        true_label.extend(labels)
        pred_label.extend(predicted)
        total += len(labels)
        correct += (predicted == labels).sum().item()
        
    print('Test Accuracy of the model on the {} test images: {} %'.format(total, 100 * correct / total))
# Out:
# 9
# tensor(0.1886, device='cuda:0', requires_grad=True)
# Test Accuracy of the model on the 2897 test images: 76.14773904038661 %

# %%
true_label
# Out:
# [tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(1, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  ...]

# %%
pred_label
# Out:
# [tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  tensor(0, device='cuda:0'),
#  ...]

# %%
true_labels=torch.tensor(true_label)
true_labels=true_labels.tolist()
pred_labels=torch.tensor(pred_label)
pred_labels=pred_labels.tolist()
print(classification_report(true_labels,pred_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.86      0.84      2155
#            1       0.54      0.47      0.50       742
#
#     accuracy                           0.76      2897
#    macro avg       0.68      0.67      0.67      2897
# weighted avg       0.75      0.76      0.76      2897

# %%
true_label1=[]
pred_label1=[]

model=CustomConvNet().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=hyper_param_learning_rate)

checkpoint = torch.load('/home/sumins/workspace/model_check/model_dropout_position.pth')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
loss = checkpoint['loss']
print(loss)
custom_model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for item in train_loader:
        npys = item['npy'].to(device)
        labels = item['label'].to(device)
        
        outputs =model(npys)
        _, predicted = torch.max(outputs.data, 1)
        true_label1.extend(labels)
        pred_label1.extend(predicted)
        total += len(labels)
        correct += (predicted == labels).sum().item()
        
    print('Test Accuracy of the model on the {} train images: {} %'.format(total, 100 * correct / total))
# Out:
# tensor(0.1886, device='cuda:0', requires_grad=True)
# Test Accuracy of the model on the 19310 train images: 92.50129466597618 %

# %%
true_labels1=torch.tensor(true_label1)
true_labels1=true_labels1.tolist()
pred_labels1=torch.tensor(pred_label1)
pred_labels1=pred_labels1.tolist()
print(classification_report(true_labels1,pred_labels1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95     13062
#            1       0.93      0.83      0.88      6248
#
#     accuracy                           0.93     19310
#    macro avg       0.93      0.90      0.91     19310
# weighted avg       0.93      0.93      0.92     19310
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다. 셀의 코드를 검토하여 오류의 가능한 원인을 식별하세요. 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'> 여기 </a> 를 클릭하세요. 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
