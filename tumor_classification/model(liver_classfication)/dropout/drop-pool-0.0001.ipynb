# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  
os.environ["CUDA_VISIBLE_DEVICES"]="6"

# %%
import numpy as np
from matplotlib import pyplot as plt
import nibabel as nib
from PIL import Image
from matplotlib import pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
from sklearn.model_selection import train_test_split
import torchsummary
from torchvision import transforms
import time
from sklearn.metrics import classification_report

# %%
#파일이름 sort해서 list저장
data_path='/disk1/data_liverbound_noclip/'
name_list=os.listdir(data_path)

segmentation_data = [files[:-4] for files in name_list if files.startswith('segmentation')]
segmentation_data=list(set(segmentation_data))
segmentation_data.sort()
seg_data_test=[]
for i in range(30,45):
    seg_data_test.append(segmentation_data.pop(i))

volume_data=[files[:-4] for files in name_list if files.startswith('volume')]
volume_data=list(set(volume_data))
volume_data.sort()
vol_data_test=[]
for i in range(30,45):
    vol_data_test.append(volume_data.pop(i))

# %%
# all_labels=np.loadtxt('/home/sumins/workspace/liver_classification/all_labels.txt',dtype=int)
# all_labels=all_labels.tolist()

# %%
#npy를 slice별로 나누어 하나의 list저장
seg_list_train=[]
seg_list_test=[]
for file in segmentation_data:
    fname=os.path.basename(file)
    print(fname)
    img_array=np.load(data_path+fname+'.npy')
    
    #print(f'img_num: {img_array.shape}')
    
    if len(img_array.shape) == 3:
        nx, ny, nz = img_array.shape
        total_slices = img_array.shape[2]
        #print(total_slices)
        # iterate through slices
        for current_slice in range(0, total_slices):
            seg_list_train.append(img_array[:,:,current_slice]) 

for file in seg_data_test:
    fname=os.path.basename(file)
    print(fname)
    img_array=np.load(data_path+fname+'.npy')
    
    #print(f'img_num: {img_array.shape}')
    
    if len(img_array.shape) == 3:
        nx, ny, nz = img_array.shape
        total_slices = img_array.shape[2]
        print(total_slices)
        # iterate through slices
        for current_slice in range(0, total_slices):
            seg_list_test.append(img_array[:,:,current_slice]) 
#간 1, 병변 2, 나머지 0


vol_list_train=[]
vol_list_test=[]
for file in volume_data:
    fname=os.path.basename(file)
    print(fname)
    img_array=np.load(data_path+fname+'.npy')
    
    #print(f'img_num: {img_array.shape}')
    
    if len(img_array.shape) == 3:
        nx, ny, nz = img_array.shape
        total_slices = img_array.shape[2]
        # iterate through slices
        for current_slice in range(0, total_slices):
            vol_list_train.append(img_array[:,:,current_slice]) 
            
for file in vol_data_test:
    fname=os.path.basename(file)
    print(fname)
    img_array=np.load(data_path+fname+'.npy')
    
    #print(f'img_num: {img_array.shape}')
    
    if len(img_array.shape) == 3:
        nx, ny, nz = img_array.shape
        total_slices = img_array.shape[2]
        # iterate through slices
        for current_slice in range(0, total_slices):
            vol_list_test.append(img_array[:,:,current_slice])
# Out:
# segmentation-0
# segmentation-1
# segmentation-10
# segmentation-100
# segmentation-101
# segmentation-102
# segmentation-103
# segmentation-104
# segmentation-105
# segmentation-106
# segmentation-107
# segmentation-108
# segmentation-109
# segmentation-11
# segmentation-110
# segmentation-111
# segmentation-112
# segmentation-113
# segmentation-114
# segmentation-115
# segmentation-116
# segmentation-117
# segmentation-118
# segmentation-119
# segmentation-12
# segmentation-120
# segmentation-121
# segmentation-122
# segmentation-123
# segmentation-124
# segmentation-126
# segmentation-128
# segmentation-13
# segmentation-15
# segmentation-17
# segmentation-19
# segmentation-20
# segmentation-22
# segmentation-24
# segmentation-26
# segmentation-28
# segmentation-3
# segmentation-31
# segmentation-33
# segmentation-35
# segmentation-36
# segmentation-37
# segmentation-38
# segmentation-39
# segmentation-4
# segmentation-40
# segmentation-41
# segmentation-42
# segmentation-43
# segmentation-44
# segmentation-45
# segmentation-46
# segmentation-47
# segmentation-48
# segmentation-49
# segmentation-5
# segmentation-50
# segmentation-51
# segmentation-52
# segmentation-53
# segmentation-54
# segmentation-55
# segmentation-56
# segmentation-57
# segmentation-58
# segmentation-59
# segmentation-6
# segmentation-60
# segmentation-61
# segmentation-62
# segmentation-63
# segmentation-64
# segmentation-65
# segmentation-66
# segmentation-67
# segmentation-68
# segmentation-69
# segmentation-7
# segmentation-70
# segmentation-71
# segmentation-72
# segmentation-73
# segmentation-74
# segmentation-75
# segmentation-76
# segmentation-77
# segmentation-78
# segmentation-79
# segmentation-8
# segmentation-80
# segmentation-81
# segmentation-82
# segmentation-83
# segmentation-84
# segmentation-85
# segmentation-86
# segmentation-87
# segmentation-88
# segmentation-89
# segmentation-9
# segmentation-90
# segmentation-91
# segmentation-92
# segmentation-93
# segmentation-94
# segmentation-95
# segmentation-96
# segmentation-97
# segmentation-98
# segmentation-99
# segmentation-125
# 133
# segmentation-127
# 270
# segmentation-129
# 325
# segmentation-14
# 164
# segmentation-16
# 222
# segmentation-18
# 224
# segmentation-2
# 164
# segmentation-21
# 191
# segmentation-23
# 137
# segmentation-25
# 277
# segmentation-27
# 272
# segmentation-29
# 135
# segmentation-30
# 146
# segmentation-32
# 128
# segmentation-34
# 109
# volume-0
# volume-1
# volume-10
# volume-100
# volume-101
# volume-102
# volume-103
# volume-104
# volume-105
# volume-106
# volume-107
# volume-108
# volume-109
# volume-11
# volume-110
# volume-111
# volume-112
# volume-113
# volume-114
# volume-115
# volume-116
# volume-117
# volume-118
# volume-119
# volume-12
# volume-120
# volume-121
# volume-122
# volume-123
# volume-124
# volume-126
# volume-128
# volume-13
# volume-15
# volume-17
# volume-19
# volume-20
# volume-22
# volume-24
# volume-26
# volume-28
# volume-3
# volume-31
# volume-33
# volume-35
# volume-36
# volume-37
# volume-38
# volume-39
# volume-4
# volume-40
# volume-41
# volume-42
# volume-43
# volume-44
# volume-45
# volume-46
# volume-47
# volume-48
# volume-49
# volume-5
# volume-50
# volume-51
# volume-52
# volume-53
# volume-54
# volume-55
# volume-56
# volume-57
# volume-58
# volume-59
# volume-6
# volume-60
# volume-61
# volume-62
# volume-63
# volume-64
# volume-65
# volume-66
# volume-67
# volume-68
# volume-69
# volume-7
# volume-70
# volume-71
# volume-72
# volume-73
# volume-74
# volume-75
# volume-76
# volume-77
# volume-78
# volume-79
# volume-8
# volume-80
# volume-81
# volume-82
# volume-83
# volume-84
# volume-85
# volume-86
# volume-87
# volume-88
# volume-89
# volume-9
# volume-90
# volume-91
# volume-92
# volume-93
# volume-94
# volume-95
# volume-96
# volume-97
# volume-98
# volume-99
# volume-125
# volume-127
# volume-129
# volume-14
# volume-16
# volume-18
# volume-2
# volume-21
# volume-23
# volume-25
# volume-27
# volume-29
# volume-30
# volume-32
# volume-34

# %%
#label을 만들어 list에 저장
labels_train = []
labels_test=[]
for i in seg_list_test:
    if 2 in i:
        labels_test.append(1)
    else:
        labels_test.append(0)
        
for i in seg_list_train:
    if 2 in i:
        labels_train.append(1)
    else:
        labels_train.append(0)

# %%
Train_True=0
Train_False=0
Test_True=0
Test_False=0

for i in labels_train:
    if i==1:
        Train_True+=1
    elif i==0:
        Train_False+=1
    else:
        print("error")

for i in labels_test:
    if i==1:
        Test_True+=1
    elif i==0:
        Test_False+=1
    else:
        print("error")

# %%
print("Train True: ",Train_True)
print("Train Flase: ",Train_False)
print("Test True: ",Test_True)
print("Test False: ",Test_False)
# Out:
# Train True:  6248
# Train Flase:  13062
# Test True:  742
# Test False:  2155

# %%
def norm(nparray):
    # normalize scans to [0,1]
    _min = nparray.min()
    _max = nparray.max()
    nparray = nparray - _min
    nparray = nparray / (_max - _min)
    return nparray

def norm_zscore(nparray):
    # normalize 2d scands by mean and standard deviation
    mean = nparray.mean()
    std = nparray.std()    
    nparray = nparray - mean
    nparray /= std
    return nparray

# %%
WINDOW_MAX = 200
WINDOW_MIN = 0
GLOBAL_PIXEL_MEAN = 0.1

class CustomDataset(Dataset): 
  def __init__(self,volume_list,all_labels,transforms=None):
    self.volume_list=volume_list
    self.all_labels=all_labels
    self.length=len(all_labels)
    self.transforms=transforms


  def __len__(self):
    return self.length


  def __getitem__(self, idx):
    npy=self.volume_list[idx]

    npy[npy > WINDOW_MAX] = WINDOW_MAX
    npy[npy < WINDOW_MIN] = WINDOW_MIN
    
    npy = (npy - WINDOW_MIN) / (WINDOW_MAX - WINDOW_MIN)
    npy -= GLOBAL_PIXEL_MEAN
    
    if len(npy.shape)==2:
      npy=npy[:,:,np.newaxis].astype(dtype='float32')
    
    if self.transforms is not None:
      npy=self.transforms(npy)
    
    return{'npy':npy,'label':self.all_labels[idx]}

# %%
class CustomConvNet(nn.Module):
    def __init__(self):
        super(CustomConvNet, self).__init__() #상속받은 class에 접근하기 위함

        self.layer1 = self.conv_module(1, 16) #흑백사진은 inp
        self.layer2 = self.conv_module(16, 32)
        self.layer3 = self.conv_module(32, 64)
        self.layer4 = self.conv_module(64, 128)
        self.layer5 = self.conv_module(128, 256)
        self.gap = self.global_avg_pool(256, 2)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        out = self.gap(out)
        out = out.view(-1, 2)

        return out

    def conv_module(self, in_num, out_num):
        return nn.Sequential(
            nn.Conv2d(in_num, out_num, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(out_num),
            nn.LeakyReLU(),
            nn.Dropout(0.4),
            nn.MaxPool2d(kernel_size=2, stride=2)
            )

    def global_avg_pool(self, in_num, out_num):
        return nn.Sequential(
            nn.Conv2d(in_num, out_num, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(out_num),
            nn.LeakyReLU(),
            nn.AdaptiveAvgPool2d((1,1)))
        
model=CustomConvNet()
torchsummary.summary(model.cuda(),input_size=(1,512,512),batch_size=1)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [1, 16, 512, 512]             160
#        BatchNorm2d-2          [1, 16, 512, 512]              32
#          LeakyReLU-3          [1, 16, 512, 512]               0
#            Dropout-4          [1, 16, 512, 512]               0
#          MaxPool2d-5          [1, 16, 256, 256]               0
#             Conv2d-6          [1, 32, 256, 256]           4,640
#        BatchNorm2d-7          [1, 32, 256, 256]              64
#          LeakyReLU-8          [1, 32, 256, 256]               0
#            Dropout-9          [1, 32, 256, 256]               0
#         MaxPool2d-10          [1, 32, 128, 128]               0
#            Conv2d-11          [1, 64, 128, 128]          18,496
#       BatchNorm2d-12          [1, 64, 128, 128]             128
#         LeakyReLU-13          [1, 64, 128, 128]               0
#           Dropout-14          [1, 64, 128, 128]               0
#         MaxPool2d-15            [1, 64, 64, 64]               0
#            Conv2d-16           [1, 128, 64, 64]          73,856
#       BatchNorm2d-17           [1, 128, 64, 64]             256
#         LeakyReLU-18           [1, 128, 64, 64]               0
#           Dropout-19           [1, 128, 64, 64]               0
#         MaxPool2d-20           [1, 128, 32, 32]               0
#            Conv2d-21           [1, 256, 32, 32]         295,168
#       BatchNorm2d-22           [1, 256, 32, 32]             512
#         LeakyReLU-23           [1, 256, 32, 32]               0
#           Dropout-24           [1, 256, 32, 32]               0
#         MaxPool2d-25           [1, 256, 16, 16]               0
#            Conv2d-26             [1, 2, 16, 16]           4,610
#       BatchNorm2d-27             [1, 2, 16, 16]               4
#         LeakyReLU-28             [1, 2, 16, 16]               0
# AdaptiveAvgPool2d-29               [1, 2, 1, 1]               0
# ================================================================
# Total params: 397,926
# Trainable params: 397,926
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 1.00
# Forward/backward pass size (MB): 263.51
# Params size (MB): 1.52
# Estimated Total Size (MB): 266.03
# ----------------------------------------------------------------

# %%
transforms_train = transforms.Compose([transforms.ToTensor()
                                       ])
transforms_test = transforms.Compose([transforms.ToTensor()
                                       ])

hyper_param_epoch=100
hyper_param_batch=32
hyper_param_learning_rate=0.0001

# %%
#vol_train, vol_valid, lab_train, lab_valid = train_test_split(volume_list, all_labels, test_size=0.3, shuffle=True, stratify=all_labels, random_state=34)
train_dataset=CustomDataset(volume_list=vol_list_train, all_labels=labels_train,transforms=transforms_train)
test_dataset=CustomDataset(volume_list=vol_list_test,all_labels=labels_test,transforms=transforms_test)
train_loader = DataLoader(train_dataset, batch_size=hyper_param_batch, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=hyper_param_batch, shuffle=True)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device,"/" ,torch.cuda.device_count())

custom_model=CustomConvNet().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(custom_model.parameters(), lr=hyper_param_learning_rate)
# Out:
# cuda:0 / 1

# %%
def validation_loss(model):
    total_loss=0
    for i_batch, item in enumerate(test_loader):
        npys = item['npy'].to(device)
        labels = item['label'].to(device)
 
        outputs =model(npys)
        loss = criterion(outputs, labels)

        total_loss+=loss.item()
    return total_loss/(i_batch+1)

# %%
loss_value=1
start=time.time()
custom_model.train()
train_loss_history=[]
valid_loss_history=[]
val_loss=0
for e in range(hyper_param_epoch):
        for i_batch, item in enumerate(train_loader):
                npys = item['npy'].to(device)
                labels = item['label'].to(device)
                #print(npys)
                # Forward pass
                outputs =custom_model(npys)
                loss = criterion(outputs, labels)

                # Backward and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
        val_loss=validation_loss(custom_model)
        train_loss_history.append(loss.item())
        valid_loss_history.append(val_loss)
        print('Epoch [{}/{}],i_batch={} ,Train_Loss: {:.4f},Valid_loss: {:.4f}'
                                        .format(e + 1, hyper_param_epoch, i_batch+1, loss.item(),val_loss))
        print("Time: {}sec".format(time.time()-start))
        start=time.time()
        if loss_value>val_loss:
                loss_value=val_loss
                torch.save({
                'epoch': e,
                'model_state_dict': custom_model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': loss,
                }, '/home/sumins/workspace/model_check/model_dropout_learningrate.pth')
# Out:
# Epoch [1/100],i_batch=604 ,Train_Loss: 0.6871,Valid_loss: 0.6000
# Time: 92.38976955413818sec
# Epoch [2/100],i_batch=604 ,Train_Loss: 0.6305,Valid_loss: 0.5995
# Time: 84.80199027061462sec
# Epoch [3/100],i_batch=604 ,Train_Loss: 0.5410,Valid_loss: 0.5931
# Time: 85.0763909816742sec
# Epoch [4/100],i_batch=604 ,Train_Loss: 0.4928,Valid_loss: 0.5891
# Time: 85.1364963054657sec
# Epoch [5/100],i_batch=604 ,Train_Loss: 0.4550,Valid_loss: 0.5573
# Time: 84.9418694972992sec
# Epoch [6/100],i_batch=604 ,Train_Loss: 0.4963,Valid_loss: 0.5767
# Time: 85.05045533180237sec
# Epoch [7/100],i_batch=604 ,Train_Loss: 0.4978,Valid_loss: 0.5510
# Time: 85.23827314376831sec
# Epoch [8/100],i_batch=604 ,Train_Loss: 0.4720,Valid_loss: 0.5571
# Time: 84.72757315635681sec
# Epoch [9/100],i_batch=604 ,Train_Loss: 0.4116,Valid_loss: 0.5514
# Time: 83.46948885917664sec
# Epoch [10/100],i_batch=604 ,Train_Loss: 0.4933,Valid_loss: 0.5329
# Time: 83.90193128585815sec
# Epoch [11/100],i_batch=604 ,Train_Loss: 0.3761,Valid_loss: 0.5404
# Time: 82.9650866985321sec
# Epoch [12/100],i_batch=604 ,Train_Loss: 0.5998,Valid_loss: 0.5307
# Time: 82.79934310913086sec
# Epoch [13/100],i_batch=604 ,Train_Loss: 0.4523,Valid_loss: 0.5210
# Time: 82.7315320968628sec
# Epoch [14/100],i_batch=604 ,Train_Loss: 0.3565,Valid_loss: 0.5156
# Time: 83.01199793815613sec
# Epoch [15/100],i_batch=604 ,Train_Loss: 0.3259,Valid_loss: 0.5329
# Time: 82.82231187820435sec
# Epoch [16/100],i_batch=604 ,Train_Loss: 0.3648,Valid_loss: 0.5261
# Time: 82.93396091461182sec
# Epoch [17/100],i_batch=604 ,Train_Loss: 0.3702,Valid_loss: 0.5119
# Time: 105.65457916259766sec
# Epoch [18/100],i_batch=604 ,Train_Loss: 0.3997,Valid_loss: 0.5235
# Time: 111.70728754997253sec
# Epoch [19/100],i_batch=604 ,Train_Loss: 0.4543,Valid_loss: 0.5145
# Time: 116.13192939758301sec
# Epoch [20/100],i_batch=604 ,Train_Loss: 0.3453,Valid_loss: 0.5366
# Time: 116.97807598114014sec
# Epoch [21/100],i_batch=604 ,Train_Loss: 0.4430,Valid_loss: 0.5114
# Time: 118.73962473869324sec
# Epoch [22/100],i_batch=604 ,Train_Loss: 0.2799,Valid_loss: 0.5229
# Time: 118.14228940010071sec
# Epoch [23/100],i_batch=604 ,Train_Loss: 0.4084,Valid_loss: 0.5181
# Time: 114.84736442565918sec
# Epoch [24/100],i_batch=604 ,Train_Loss: 0.4313,Valid_loss: 0.5055
# Time: 125.90546107292175sec
# Epoch [25/100],i_batch=604 ,Train_Loss: 0.4630,Valid_loss: 0.4972
# Time: 119.55573153495789sec
# Epoch [26/100],i_batch=604 ,Train_Loss: 0.3875,Valid_loss: 0.5334
# Time: 122.94017887115479sec
# Epoch [27/100],i_batch=604 ,Train_Loss: 0.4996,Valid_loss: 0.5091
# Time: 129.67328023910522sec
# Epoch [28/100],i_batch=604 ,Train_Loss: 0.2913,Valid_loss: 0.5194
# Time: 148.7900846004486sec
# Epoch [29/100],i_batch=604 ,Train_Loss: 0.2523,Valid_loss: 0.5049
# Time: 162.6756010055542sec
# Epoch [30/100],i_batch=604 ,Train_Loss: 0.3483,Valid_loss: 0.4910
# Time: 184.06025171279907sec
# Epoch [31/100],i_batch=604 ,Train_Loss: 0.3488,Valid_loss: 0.5141
# Time: 199.71774554252625sec
# Epoch [32/100],i_batch=604 ,Train_Loss: 0.2468,Valid_loss: 0.4922
# Time: 230.41945791244507sec
# Epoch [33/100],i_batch=604 ,Train_Loss: 0.2914,Valid_loss: 0.5275
# Time: 207.56360292434692sec
# Epoch [34/100],i_batch=604 ,Train_Loss: 0.2317,Valid_loss: 0.5145
# Time: 128.65928530693054sec
# Epoch [35/100],i_batch=604 ,Train_Loss: 0.1632,Valid_loss: 0.5099
# Time: 83.81878995895386sec
# Epoch [36/100],i_batch=604 ,Train_Loss: 0.1507,Valid_loss: 0.5086
# Time: 84.57489347457886sec
# Epoch [37/100],i_batch=604 ,Train_Loss: 0.1910,Valid_loss: 0.5024
# Time: 84.20432329177856sec
# Epoch [38/100],i_batch=604 ,Train_Loss: 0.2622,Valid_loss: 0.4956
# Time: 84.16761326789856sec
# Epoch [39/100],i_batch=604 ,Train_Loss: 0.3215,Valid_loss: 0.4937
# Time: 84.42437171936035sec
# Epoch [40/100],i_batch=604 ,Train_Loss: 0.1976,Valid_loss: 0.5445
# Time: 87.60954666137695sec
# Epoch [41/100],i_batch=604 ,Train_Loss: 0.3821,Valid_loss: 0.5188
# Time: 309.3090102672577sec
# Epoch [42/100],i_batch=604 ,Train_Loss: 0.2026,Valid_loss: 0.5108
# Time: 186.89871311187744sec
# Epoch [43/100],i_batch=604 ,Train_Loss: 0.1693,Valid_loss: 0.5057
# Time: 194.17934346199036sec
# Epoch [44/100],i_batch=604 ,Train_Loss: 0.2158,Valid_loss: 0.5243
# Time: 291.6525378227234sec
# Epoch [45/100],i_batch=604 ,Train_Loss: 0.1402,Valid_loss: 0.4857
# Time: 163.35804533958435sec
# Epoch [46/100],i_batch=604 ,Train_Loss: 0.1733,Valid_loss: 0.4738
# Time: 182.70113325119019sec
# Epoch [47/100],i_batch=604 ,Train_Loss: 0.1133,Valid_loss: 0.4882
# Time: 175.0846767425537sec
# Epoch [48/100],i_batch=604 ,Train_Loss: 0.1247,Valid_loss: 0.5095
# Time: 175.46522331237793sec
# Epoch [49/100],i_batch=604 ,Train_Loss: 0.1944,Valid_loss: 0.4741
# Time: 176.68937754631042sec
# Epoch [50/100],i_batch=604 ,Train_Loss: 0.1481,Valid_loss: 0.4753
# Time: 183.64022183418274sec
# Epoch [51/100],i_batch=604 ,Train_Loss: 0.2587,Valid_loss: 0.4910
# Time: 175.20312547683716sec
# Epoch [52/100],i_batch=604 ,Train_Loss: 0.0856,Valid_loss: 0.4717
# Time: 180.6068925857544sec
# Epoch [53/100],i_batch=604 ,Train_Loss: 0.4155,Valid_loss: 0.4587
# Time: 188.64880466461182sec
# Epoch [54/100],i_batch=604 ,Train_Loss: 0.3159,Valid_loss: 0.4721
# Time: 185.4720573425293sec
# Epoch [55/100],i_batch=604 ,Train_Loss: 0.1019,Valid_loss: 0.4935
# Time: 178.20893383026123sec
# Epoch [56/100],i_batch=604 ,Train_Loss: 0.2172,Valid_loss: 0.5097
# Time: 186.16714906692505sec
# Epoch [57/100],i_batch=604 ,Train_Loss: 0.1086,Valid_loss: 0.4951
# Time: 189.03956604003906sec
# Epoch [58/100],i_batch=604 ,Train_Loss: 0.1031,Valid_loss: 0.4863
# Time: 182.86341071128845sec
# Epoch [59/100],i_batch=604 ,Train_Loss: 0.1460,Valid_loss: 0.5086
# Time: 184.33883833885193sec
# Epoch [60/100],i_batch=604 ,Train_Loss: 0.0946,Valid_loss: 0.5275
# Time: 180.64855313301086sec
# Epoch [61/100],i_batch=604 ,Train_Loss: 0.0804,Valid_loss: 0.4840
# Time: 169.4806146621704sec
# Epoch [62/100],i_batch=604 ,Train_Loss: 0.1120,Valid_loss: 0.4786
# Time: 176.8658218383789sec
# Epoch [63/100],i_batch=604 ,Train_Loss: 0.1878,Valid_loss: 0.5462
# Time: 208.9098768234253sec
# Epoch [64/100],i_batch=604 ,Train_Loss: 0.4118,Valid_loss: 0.5222
# Time: 86.03852915763855sec
# Epoch [65/100],i_batch=604 ,Train_Loss: 0.0880,Valid_loss: 0.5240
# Time: 83.25236010551453sec
# Epoch [66/100],i_batch=604 ,Train_Loss: 0.1323,Valid_loss: 0.5632
# Time: 83.4325954914093sec
# Epoch [67/100],i_batch=604 ,Train_Loss: 0.0918,Valid_loss: 0.5211
# Time: 84.04330968856812sec
# Epoch [68/100],i_batch=604 ,Train_Loss: 0.2113,Valid_loss: 0.5309
# Time: 84.33772587776184sec
# Epoch [69/100],i_batch=604 ,Train_Loss: 0.3759,Valid_loss: 0.5461
# Time: 84.53954482078552sec
# Epoch [70/100],i_batch=604 ,Train_Loss: 0.1274,Valid_loss: 0.5472
# Time: 84.19963550567627sec
# Epoch [71/100],i_batch=604 ,Train_Loss: 0.1274,Valid_loss: 0.4920
# Time: 84.49193716049194sec
# Epoch [72/100],i_batch=604 ,Train_Loss: 0.0930,Valid_loss: 0.5043
# Time: 84.2282783985138sec
# Epoch [73/100],i_batch=604 ,Train_Loss: 0.2125,Valid_loss: 0.5025
# Time: 85.14700698852539sec
# Epoch [74/100],i_batch=604 ,Train_Loss: 0.1403,Valid_loss: 0.5110
# Time: 85.42400074005127sec
# Epoch [75/100],i_batch=604 ,Train_Loss: 0.0688,Valid_loss: 0.4841
# Time: 85.20393681526184sec
# Epoch [76/100],i_batch=604 ,Train_Loss: 0.2783,Valid_loss: 0.4979
# Time: 84.86285066604614sec
# Epoch [77/100],i_batch=604 ,Train_Loss: 0.1025,Valid_loss: 0.5391
# Time: 85.16614389419556sec
# Epoch [78/100],i_batch=604 ,Train_Loss: 0.0647,Valid_loss: 0.4965
# Time: 84.41429662704468sec
# Epoch [79/100],i_batch=604 ,Train_Loss: 0.2453,Valid_loss: 0.5263
# Time: 84.72499370574951sec
# Epoch [80/100],i_batch=604 ,Train_Loss: 0.0924,Valid_loss: 0.5297
# Time: 83.79538226127625sec
# Epoch [81/100],i_batch=604 ,Train_Loss: 0.0594,Valid_loss: 0.5213
# Time: 84.46778678894043sec
# Epoch [82/100],i_batch=604 ,Train_Loss: 0.1054,Valid_loss: 0.5005
# Time: 84.44087767601013sec
# Epoch [83/100],i_batch=604 ,Train_Loss: 0.1426,Valid_loss: 0.4738
# Time: 84.96610140800476sec
# Epoch [84/100],i_batch=604 ,Train_Loss: 0.0836,Valid_loss: 0.5049
# Time: 84.35755586624146sec
# Epoch [85/100],i_batch=604 ,Train_Loss: 0.3595,Valid_loss: 0.5373
# Time: 85.7652645111084sec
# Epoch [86/100],i_batch=604 ,Train_Loss: 0.0617,Valid_loss: 0.5162
# Time: 86.32209324836731sec
# Epoch [87/100],i_batch=604 ,Train_Loss: 0.1097,Valid_loss: 0.5543
# Time: 120.18315196037292sec
# Epoch [88/100],i_batch=604 ,Train_Loss: 0.0572,Valid_loss: 0.4732
# Time: 85.20678544044495sec
# Epoch [89/100],i_batch=604 ,Train_Loss: 0.0764,Valid_loss: 0.4974
# Time: 84.00286841392517sec
# Epoch [90/100],i_batch=604 ,Train_Loss: 0.0601,Valid_loss: 0.5138
# Time: 84.78093552589417sec
# Epoch [91/100],i_batch=604 ,Train_Loss: 0.1043,Valid_loss: 0.4885
# Time: 85.14907646179199sec
# Epoch [92/100],i_batch=604 ,Train_Loss: 0.1189,Valid_loss: 0.5261
# Time: 84.66018056869507sec
# Epoch [93/100],i_batch=604 ,Train_Loss: 0.1324,Valid_loss: 0.5168
# Time: 83.68731617927551sec
# Epoch [94/100],i_batch=604 ,Train_Loss: 0.0281,Valid_loss: 0.5261
# Time: 85.00330090522766sec
# Epoch [95/100],i_batch=604 ,Train_Loss: 0.0279,Valid_loss: 0.5333
# Time: 249.58994317054749sec
# Epoch [96/100],i_batch=604 ,Train_Loss: 0.0480,Valid_loss: 0.5523
# Time: 230.79626059532166sec
# Epoch [97/100],i_batch=604 ,Train_Loss: 0.0651,Valid_loss: 0.5379
# Time: 84.46969509124756sec
# Epoch [98/100],i_batch=604 ,Train_Loss: 0.0394,Valid_loss: 0.5570
# Time: 114.7326910495758sec
# Epoch [99/100],i_batch=604 ,Train_Loss: 0.0668,Valid_loss: 0.5012
# Time: 230.25181484222412sec
# Epoch [100/100],i_batch=604 ,Train_Loss: 0.0360,Valid_loss: 0.5300
# Time: 84.06559443473816sec

# %%
plt.plot(train_loss_history)
plt.plot(valid_loss_history)
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
import csv


with open("valid_dropout_learningrate.csv", 'w') as file:
  writer = csv.writer(file)
  writer.writerow(valid_loss_history)

# %%
import csv


with open("train_dropout_learningrate.csv", 'w') as file:
  writer = csv.writer(file)
  writer.writerow(train_loss_history)

# %%
true_label=[]
pred_label=[]

model=CustomConvNet().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=hyper_param_learning_rate)

checkpoint = torch.load('/home/sumins/workspace/model_check/model_dropout_learningrate.pth')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
loss = checkpoint['loss']
print(epoch)
print(loss)
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for item in test_loader:
        npys = item['npy'].to(device)
        labels = item['label'].to(device)
        
        outputs =model(npys)
        _, predicted = torch.max(outputs.data, 1)
        true_label.extend(labels)
        pred_label.extend(predicted)
        total += len(labels)
        correct += (predicted == labels).sum().item()
       
    print('Test Accuracy of the model on the {} test images: {} %'.format(total, 100 * correct / total))
# Out:
# 52
# tensor(0.4155, device='cuda:0', requires_grad=True)
# Test Accuracy of the model on the 2897 test images: 68.69175008629617 %

# %%
print(total)
print(correct)
# Out:
# 2897
# 1990

# %%
true_labels=torch.tensor(true_label)
true_labels=true_labels.tolist()
pred_labels=torch.tensor(pred_label)
pred_labels=pred_labels.tolist()
print(classification_report(true_labels,pred_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.74      0.78      2155
#            1       0.42      0.55      0.47       742
#
#     accuracy                           0.69      2897
#    macro avg       0.62      0.64      0.62      2897
# weighted avg       0.72      0.69      0.70      2897

# %%
true_label1=[]
pred_label1=[]

model=CustomConvNet().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=hyper_param_learning_rate)

checkpoint = torch.load('/home/sumins/workspace/model_check/model_dropout_learningrate.pth')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
loss = checkpoint['loss']
print(loss)
custom_model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for item in train_loader:
        npys = item['npy'].to(device)
        labels = item['label'].to(device)
        
        outputs =model(npys)
        _, predicted = torch.max(outputs.data, 1)
        true_label1.extend(labels)
        pred_label1.extend(predicted)
        total += len(labels)
        correct += (predicted == labels).sum().item()
        
    print('Test Accuracy of the model on the {} train images: {} %'.format(total, 100 * correct / total))
# Out:
# tensor(0.4155, device='cuda:0', requires_grad=True)
# Test Accuracy of the model on the 19310 train images: 95.99689280165717 %

# %%
true_labels1=torch.tensor(true_label1)
true_labels1=true_labels1.tolist()
pred_labels1=torch.tensor(pred_label1)
pred_labels1=pred_labels1.tolist()
print(classification_report(true_labels1,pred_labels1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     13062
#            1       0.96      0.91      0.94      6248
#
#     accuracy                           0.96     19310
#    macro avg       0.96      0.95      0.95     19310
# weighted avg       0.96      0.96      0.96     19310
